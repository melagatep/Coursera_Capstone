# %% [markdown]
# # Data Science Project

# %% [markdown]
# ### by Mel Agatep
# <br>
# <br>
# <br>

# %% [markdown]
# ## Data Section <a name="data"></a>

# %% [markdown]
# #### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     openssl-1.1.1g             |       h516909a_0         2.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#
# The following packages will be UPDATED:
#
#   openssl                                 1.1.1f-h516909a_0 --> 1.1.1g-h516909a_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1g       | 2.1 MB    | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     altair-4.1.0               |             py_1         614 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     brotlipy-0.7.0             |py36h8c4c3a4_1000         346 KB  conda-forge
#     chardet-3.0.4              |py36h9f0ad1d_1006         188 KB  conda-forge
#     cryptography-2.9.2         |   py36h45558ae_0         613 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     pandas-1.0.3               |   py36h830a2c2_1        11.1 MB  conda-forge
#     pysocks-1.7.1              |   py36h9f0ad1d_1          27 KB  conda-forge
#     pytz-2020.1                |     pyh9f0ad1d_0         227 KB  conda-forge
#     toolz-0.10.0               |             py_0          46 KB  conda-forge
#     urllib3-1.25.9             |             py_0          92 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        13.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   altair             conda-forge/noarch::altair-4.1.0-py_1
#   attrs              conda-forge/noarch::attrs-19.3.0-py_0
#   branca             conda-forge/noarch::branca-0.4.0-py_0
#   brotlipy           conda-forge/linux-64::brotlipy-0.7.0-py36h8c4c3a4_1000
#   chardet            conda-forge/linux-64::chardet-3.0.4-py36h9f0ad1d_1006
#   cryptography       conda-forge/linux-64::cryptography-2.9.2-py36h45558ae_0
#   entrypoints        conda-forge/linux-64::entrypoints-0.3-py36h9f0ad1d_1001
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   idna               conda-forge/noarch::idna-2.9-py_1
#   importlib-metadata conda-forge/linux-64::importlib-metadata-1.6.0-py36h9f0ad1d_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-1.6.0-0
#   jinja2             conda-forge/noarch::jinja2-2.11.2-pyh9f0ad1d_0
#   jsonschema         conda-forge/linux-64::jsonschema-3.2.0-py36h9f0ad1d_1
#   markupsafe         conda-forge/linux-64::markupsafe-1.1.1-py36h8c4c3a4_1
#   pandas             conda-forge/linux-64::pandas-1.0.3-py36h830a2c2_1
#   pyopenssl          conda-forge/noarch::pyopenssl-19.1.0-py_1
#   pyrsistent         conda-forge/linux-64::pyrsistent-0.16.0-py36h8c4c3a4_0
#   pysocks            conda-forge/linux-64::pysocks-1.7.1-py36h9f0ad1d_1
#   pytz               conda-forge/noarch::pytz-2020.1-pyh9f0ad1d_0
#   requests           conda-forge/noarch::requests-2.23.0-pyh8c360ce_2
#   toolz              conda-forge/noarch::toolz-0.10.0-py_0
#   urllib3            conda-forge/noarch::urllib3-1.25.9-py_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#   zipp               conda-forge/noarch::zipp-3.1.0-py_0
#
#
#
# Downloading and Extracting Packages
# pysocks-1.7.1        | 27 KB     | ##################################### | 100%
# toolz-0.10.0         | 46 KB     | ##################################### | 100%
# pytz-2020.1          | 227 KB    | ##################################### | 100%
# chardet-3.0.4        | 188 KB    | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# urllib3-1.25.9       | 92 KB     | ##################################### | 100%
# cryptography-2.9.2   | 613 KB    | ##################################### | 100%
# brotlipy-0.7.0       | 346 KB    | ##################################### | 100%
# pandas-1.0.3         | 11.1 MB   | ##################################### | 100%
# altair-4.1.0         | 614 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Folium installed
# Libraries imported.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH' # your Foursquare ID
CLIENT_SECRET = 'FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH
# CLIENT_SECRET:FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS

# %%
# Use geopy library to get the latitude and longitude values of Downtown Toronto

address = 'Downtown Toronto, ON'
geolocator = Nominatim(user_agent="Downtown_Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6563221, -79.3809161.

# %% [markdown]
# <br>
#
# ### The Search for a specific venue

# %% [markdown]
# Imagine our targeted audience (Cuisine Connoisseurs, Food Enthusiast and Bloggers) is in a downtown area using the Restaurant Guide App and wanted to find great budget-friendly restaurants. It is a busy town, a quick comparison of several venues in close proximity would be ideal for they're always on the go.
# <br>

# %%
# define a query to search for Restaurant within 500 metres from Downtown Toronto

search_query = 'Restaurant'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# #### Define the corresponding URL and limit = 10

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH&client_secret=FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS&ll=43.6563221,-79.3809161&v=20180604&query=Restaurant&radius=500&limit=10'

# %% [markdown]
# #### Make the call to foursquare api; send GET Request and examine results

# %%
results = requests.get(url).json()
results

# To simplify, output was cleared
# Out:
# {'meta': {'code': 200, 'requestId': '5eabcb92211536324bfcc0b2'},
#  'response': {'venues': [{'id': '4ad4c05ff964a52048f720e3',
#     'name': 'Hemispheres Restaurant & Bistro',
#     'location': {'address': '110 Chestnut Street',
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'distance': 434,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '4edbccaaf9abeea3db5268df',
#     'name': 'Terrace Restaurant at Elmwood',
#     'location': {'lat': 43.65610066909799,
#      'lng': -79.38148016065777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610066909799,
#        'lng': -79.38148016065777}],
#      'distance': 51,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '4fbbb3ace4b01e39077b4d55',
#     'name': 'Akashiro Japanese Restaurant & Bar',
#     'location': {'address': '220 Yonge St.',
#      'crossStreet': 'in Toronto Eaton Centre Urban Eatery',
#      'lat': 43.65596504293232,
#      'lng': -79.38054070644233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65596504293232,
#        'lng': -79.38054070644233}],
#      'distance': 49,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '53ae6660498e1ac3c1282743',
#     'name': 'Castries Bar & Five Way Restaurant',
#     'location': {'lat': 43.654727935791016,
#      'lng': -79.38092803955078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654727935791016,
#        'lng': -79.38092803955078}],
#      'distance': 177,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '4c6abb8c2c29d13ad2720e41',
#     'name': 'Subway',
#     'location': {'address': '10 Dundas St E, No 337',
#      'crossStreet': 'at Yonge St.',
#      'lat': 43.6564939,
#      'lng': -79.3807983,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6564939,
#        'lng': -79.3807983}],
#      'distance': 21,
#      'postalCode': 'M5B 2G9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Dundas St E, No 337 (at Yonge St.)',
#       'Toronto ON M5B 2G9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '56dd9d68498eb4e5edcb30f9',
#     'name': 'Spring Rolls | Japanese Restaurant in Toronto',
#     'location': {'address': '40 Dundas St W Box 36,',
#      'lat': 43.65610515821675,
#      'lng': -79.38349485397339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610515821675,
#        'lng': -79.38349485397339}],
#      'distance': 209,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['40 Dundas St W Box 36,',
#       'Toronto ON M5G 2C2',
#       'Canada']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '5165c333e4b07a7ad88d8a69',
#     'name': "Joe's Indian Restaurant",
#     'location': {'lat': 43.65814977325445,
#      'lng': -79.38156263736568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65814977325445,
#        'lng': -79.38156263736568}],
#      'distance': 210,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '4ae9ef82f964a520cbb721e3',
#     'name': 'Alio Restaurant & Wine Bar',
#     'location': {'address': '108 Dundas St W',
#      'crossStreet': 'at Bay St.',
#      'lat': 43.65565507065502,
#      'lng': -79.3841236014983,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65565507065502,
#        'lng': -79.3841236014983}],
#      'distance': 268,
#      'postalCode': 'M5G 1C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Dundas St W (at Bay St.)',
#       'Toronto ON M5G 1C3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a52070f720e3',
#     'name': 'Adega Restaurant',
#     'location': {'address': '33 Elm St',
#      'crossStreet': 'at Bay St',
#      'lat': 43.65751886446546,
#      'lng': -79.38346181502347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65751886446546,
#        'lng': -79.38346181502347}],
#      'distance': 244,
#      'postalCode': 'M5G 1H1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['33 Elm St (at Bay St)',
#       'Toronto ON M5G 1H1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1588317361',
#     'hasPerk': False},
#    {'id': '4b2027b5f964a520f82d24e3',
#     'name': 'Hong Shing Chinese Restaurant',
#     'location': {'address': '195 Dundas St W',
#      'crossStreet': 'at University Ave',
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'distance': 520,
#      'postalCode': 'M5G 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '60327598'},
#     'referralId': 'v-1588317361',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                name  \
# 0  4ad4c05ff964a52048f720e3     Hemispheres Restaurant & Bistro
# 1  4edbccaaf9abeea3db5268df       Terrace Restaurant at Elmwood
# 2  4fbbb3ace4b01e39077b4d55  Akashiro Japanese Restaurant & Bar
# 3  53ae6660498e1ac3c1282743  Castries Bar & Five Way Restaurant
# 4  4c6abb8c2c29d13ad2720e41                              Subway
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1588317361    False
# 1  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1588317361    False
# 2  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1588317361    False
# 3  [{'id': '4bf58dd8d48988d144941735', 'name': 'C...  v-1588317361    False
# 4  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...  v-1588317361    False
#
#          location.address  location.lat  location.lng  \
# 0     110 Chestnut Street     43.654884    -79.385931
# 1                     NaN     43.656101    -79.381480
# 2           220 Yonge St.     43.655965    -79.380541
# 3                     NaN     43.654728    -79.380928
# 4  10 Dundas St E, No 337     43.656494    -79.380798
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                434
# 1  [{'label': 'display', 'lat': 43.65610066909799...                 51
# 2  [{'label': 'display', 'lat': 43.65596504293232...                 49
# 3  [{'label': 'display', 'lat': 43.65472793579101...                177
# 4  [{'label': 'display', 'lat': 43.6564939, 'lng'...                 21
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1                 NaN          CA           NaN            NaN
# 2                 NaN          CA       Toronto             ON
# 3                 NaN          CA           NaN            NaN
# 4             M5B 2G9          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada                                           [Canada]
# 2           Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 3           Canada                                           [Canada]
# 4           Canada  [10 Dundas St E, No 337 (at Yonge St.), Toront...
#
#                    location.crossStreet venuePage.id
# 0                                   NaN          NaN
# 1                                   NaN          NaN
# 2  in Toronto Eaton Centre Urban Eatery          NaN
# 3                                   NaN          NaN
# 4                          at Yonge St.          NaN

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                             name            categories  \
# 0                Hemispheres Restaurant & Bistro   American Restaurant
# 1                  Terrace Restaurant at Elmwood   American Restaurant
# 2             Akashiro Japanese Restaurant & Bar      Sushi Restaurant
# 3             Castries Bar & Five Way Restaurant  Caribbean Restaurant
# 4                                         Subway        Sandwich Place
# 5  Spring Rolls | Japanese Restaurant in Toronto      Theme Restaurant
# 6                        Joe's Indian Restaurant     Indian Restaurant
# 7                     Alio Restaurant & Wine Bar    Italian Restaurant
# 8                               Adega Restaurant            Restaurant
# 9                  Hong Shing Chinese Restaurant    Chinese Restaurant
#
#                   address        lat        lng  \
# 0     110 Chestnut Street  43.654884 -79.385931
# 1                     NaN  43.656101 -79.381480
# 2           220 Yonge St.  43.655965 -79.380541
# 3                     NaN  43.654728 -79.380928
# 4  10 Dundas St E, No 337  43.656494 -79.380798
# 5  40 Dundas St W Box 36,  43.656105 -79.383495
# 6                     NaN  43.658150 -79.381563
# 7         108 Dundas St W  43.655655 -79.384124
# 8               33 Elm St  43.657519 -79.383462
# 9         195 Dundas St W  43.654925 -79.387089
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...       434    M5G 1R3  CA
# 1  [{'label': 'display', 'lat': 43.65610066909799...        51        NaN  CA
# 2  [{'label': 'display', 'lat': 43.65596504293232...        49        NaN  CA
# 3  [{'label': 'display', 'lat': 43.65472793579101...       177        NaN  CA
# 4  [{'label': 'display', 'lat': 43.6564939, 'lng'...        21    M5B 2G9  CA
# 5  [{'label': 'display', 'lat': 43.65610515821675...       209    M5G 2C2  CA
# 6  [{'label': 'display', 'lat': 43.65814977325445...       210        NaN  CA
# 7  [{'label': 'display', 'lat': 43.65565507065502...       268    M5G 1C3  CA
# 8  [{'label': 'display', 'lat': 43.65751886446546...       244    M5G 1H1  CA
# 9  [{'label': 'display', 'lat': 43.65492521335936...       520    M5G 1C7  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1      NaN   NaN  Canada                                           [Canada]
# 2  Toronto    ON  Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 3      NaN   NaN  Canada                                           [Canada]
# 4  Toronto    ON  Canada  [10 Dundas St E, No 337 (at Yonge St.), Toront...
# 5  Toronto    ON  Canada  [40 Dundas St W Box 36,, Toronto ON M5G 2C2, C...
# 6      NaN   NaN  Canada                                           [Canada]
# 7  Toronto    ON  Canada  [108 Dundas St W (at Bay St.), Toronto ON M5G ...
# 8  Toronto    ON  Canada  [33 Elm St (at Bay St), Toronto ON M5G 1H1, Ca...
# 9  Toronto    ON  Canada  [195 Dundas St W (at University Ave), Toronto ...
#
#                             crossStreet                        id
# 0                                   NaN  4ad4c05ff964a52048f720e3
# 1                                   NaN  4edbccaaf9abeea3db5268df
# 2  in Toronto Eaton Centre Urban Eatery  4fbbb3ace4b01e39077b4d55
# 3                                   NaN  53ae6660498e1ac3c1282743
# 4                          at Yonge St.  4c6abb8c2c29d13ad2720e41
# 5                                   NaN  56dd9d68498eb4e5edcb30f9
# 6                                   NaN  5165c333e4b07a7ad88d8a69
# 7                            at Bay St.  4ae9ef82f964a520cbb721e3
# 8                             at Bay St  4ad4c060f964a52070f720e3
# 9                     at University Ave  4b2027b5f964a520f82d24e3

# %%
dataframe_filtered.name
# Out:
# 0                  Hemispheres Restaurant & Bistro
# 1                    Terrace Restaurant at Elmwood
# 2               Akashiro Japanese Restaurant & Bar
# 3               Castries Bar & Five Way Restaurant
# 4                                           Subway
# 5    Spring Rolls | Japanese Restaurant in Toronto
# 6                          Joe's Indian Restaurant
# 7                       Alio Restaurant & Wine Bar
# 8                                 Adega Restaurant
# 9                    Hong Shing Chinese Restaurant
# Name: name, dtype: object

# %% [markdown]
# <br>
#
# ### Map of The City’s Downtown Area

# %% [markdown]
# Would it be convenient if we could show our targeted audience the map of their search. Also this will show them how far they are from a prospective venue.

# %%
# Let’s locate the approximate center and explore neighboring restaurants
# Zoom in to visualize
# Note: Github may not display map

venues_map = folium.Map(location=[latitude, longitude], zoom_start=10) # generate map centred around 

# add a red circle marker to represent 
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Downtown Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Approximate Defined Center: Google Maps

# %% [markdown]
# We searched cordinate 43.6563221, -79.3809161 for Downtown Toronto in google maps. Result will shows "418 The PATH - Yonge-Dundas Square, Toronto, ON M5B 1R4, Canada". This is our approximate defined center and represented by a red circle marker from the generated map above. Using the result, we can test venue location accuracy and other information.

# %% [markdown]
# #### Dataframe Clean Up

# %%
# Let's sort by distance
sort_by_distance = dataframe_filtered.sort_values('distance')
sort_by_distance
# Out:
#                                             name            categories  \
# 4                                         Subway        Sandwich Place
# 2             Akashiro Japanese Restaurant & Bar      Sushi Restaurant
# 1                  Terrace Restaurant at Elmwood   American Restaurant
# 3             Castries Bar & Five Way Restaurant  Caribbean Restaurant
# 5  Spring Rolls | Japanese Restaurant in Toronto      Theme Restaurant
# 6                        Joe's Indian Restaurant     Indian Restaurant
# 8                               Adega Restaurant            Restaurant
# 7                     Alio Restaurant & Wine Bar    Italian Restaurant
# 0                Hemispheres Restaurant & Bistro   American Restaurant
# 9                  Hong Shing Chinese Restaurant    Chinese Restaurant
#
#                   address        lat        lng  \
# 4  10 Dundas St E, No 337  43.656494 -79.380798
# 2           220 Yonge St.  43.655965 -79.380541
# 1                     NaN  43.656101 -79.381480
# 3                     NaN  43.654728 -79.380928
# 5  40 Dundas St W Box 36,  43.656105 -79.383495
# 6                     NaN  43.658150 -79.381563
# 8               33 Elm St  43.657519 -79.383462
# 7         108 Dundas St W  43.655655 -79.384124
# 0     110 Chestnut Street  43.654884 -79.385931
# 9         195 Dundas St W  43.654925 -79.387089
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 4  [{'label': 'display', 'lat': 43.6564939, 'lng'...        21    M5B 2G9  CA
# 2  [{'label': 'display', 'lat': 43.65596504293232...        49        NaN  CA
# 1  [{'label': 'display', 'lat': 43.65610066909799...        51        NaN  CA
# 3  [{'label': 'display', 'lat': 43.65472793579101...       177        NaN  CA
# 5  [{'label': 'display', 'lat': 43.65610515821675...       209    M5G 2C2  CA
# 6  [{'label': 'display', 'lat': 43.65814977325445...       210        NaN  CA
# 8  [{'label': 'display', 'lat': 43.65751886446546...       244    M5G 1H1  CA
# 7  [{'label': 'display', 'lat': 43.65565507065502...       268    M5G 1C3  CA
# 0  [{'label': 'display', 'lat': 43.65488413420439...       434    M5G 1R3  CA
# 9  [{'label': 'display', 'lat': 43.65492521335936...       520    M5G 1C7  CA
#
#       city state country                                   formattedAddress  \
# 4  Toronto    ON  Canada  [10 Dundas St E, No 337 (at Yonge St.), Toront...
# 2  Toronto    ON  Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 1      NaN   NaN  Canada                                           [Canada]
# 3      NaN   NaN  Canada                                           [Canada]
# 5  Toronto    ON  Canada  [40 Dundas St W Box 36,, Toronto ON M5G 2C2, C...
# 6      NaN   NaN  Canada                                           [Canada]
# 8  Toronto    ON  Canada  [33 Elm St (at Bay St), Toronto ON M5G 1H1, Ca...
# 7  Toronto    ON  Canada  [108 Dundas St W (at Bay St.), Toronto ON M5G ...
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 9  Toronto    ON  Canada  [195 Dundas St W (at University Ave), Toronto ...
#
#                             crossStreet                        id
# 4                          at Yonge St.  4c6abb8c2c29d13ad2720e41
# 2  in Toronto Eaton Centre Urban Eatery  4fbbb3ace4b01e39077b4d55
# 1                                   NaN  4edbccaaf9abeea3db5268df
# 3                                   NaN  53ae6660498e1ac3c1282743
# 5                                   NaN  56dd9d68498eb4e5edcb30f9
# 6                                   NaN  5165c333e4b07a7ad88d8a69
# 8                             at Bay St  4ad4c060f964a52070f720e3
# 7                            at Bay St.  4ae9ef82f964a520cbb721e3
# 0                                   NaN  4ad4c05ff964a52048f720e3
# 9                     at University Ave  4b2027b5f964a520f82d24e3

# %%
# Hide the index
sort_by_distance.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7" ><thead>    <tr>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >categories</th>        <th class="col_heading level0 col2" >address</th>        <th class="col_heading level0 col3" >lat</th>        <th class="col_heading level0 col4" >lng</th>        <th class="col_heading level0 col5" >labeledLatLngs</th>        <th class="col_heading level0 col6" >distance</th>        <th class="col_heading level0 col7" >postalCode</th>        <th class="col_heading level0 col8" >cc</th>        <th class="col_heading level0 col9" >city</th>        <th class="col_heading level0 col10" >state</th>        <th class="col_heading level0 col11" >country</th>        <th class="col_heading level0 col12" >formattedAddress</th>        <th class="col_heading level0 col13" >crossStreet</th>        <th class="col_heading level0 col14" >id</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col0" class="data row0 col0" >Subway</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col1" class="data row0 col1" >Sandwich Place</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col2" class="data row0 col2" >10 Dundas St E, No 337</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col3" class="data row0 col3" >43.656494</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col4" class="data row0 col4" >-79.380798</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col5" class="data row0 col5" >[{'label': 'display', 'lat': 43.6564939, 'lng': -79.3807983}]</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col6" class="data row0 col6" >21</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col7" class="data row0 col7" >M5B 2G9</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col8" class="data row0 col8" >CA</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col9" class="data row0 col9" >Toronto</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col10" class="data row0 col10" >ON</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col11" class="data row0 col11" >Canada</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col12" class="data row0 col12" >['10 Dundas St E, No 337 (at Yonge St.)', 'Toronto ON M5B 2G9', 'Canada']</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col13" class="data row0 col13" >at Yonge St.</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row0_col14" class="data row0 col14" >4c6abb8c2c29d13ad2720e41</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col0" class="data row1 col0" >Akashiro Japanese Restaurant & Bar</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col1" class="data row1 col1" >Sushi Restaurant</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col2" class="data row1 col2" >220 Yonge St.</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col3" class="data row1 col3" >43.655965</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col4" class="data row1 col4" >-79.380541</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col5" class="data row1 col5" >[{'label': 'display', 'lat': 43.65596504293232, 'lng': -79.38054070644233}]</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col6" class="data row1 col6" >49</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col8" class="data row1 col8" >CA</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col9" class="data row1 col9" >Toronto</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col10" class="data row1 col10" >ON</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col11" class="data row1 col11" >Canada</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col12" class="data row1 col12" >['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)', 'Toronto ON', 'Canada']</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col13" class="data row1 col13" >in Toronto Eaton Centre Urban Eatery</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row1_col14" class="data row1 col14" >4fbbb3ace4b01e39077b4d55</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col0" class="data row2 col0" >Terrace Restaurant at Elmwood</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col1" class="data row2 col1" >American Restaurant</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col3" class="data row2 col3" >43.656101</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col4" class="data row2 col4" >-79.381480</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col5" class="data row2 col5" >[{'label': 'display', 'lat': 43.65610066909799, 'lng': -79.38148016065777}]</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col6" class="data row2 col6" >51</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col7" class="data row2 col7" >nan</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col8" class="data row2 col8" >CA</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col9" class="data row2 col9" >nan</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col11" class="data row2 col11" >Canada</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col12" class="data row2 col12" >['Canada']</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col13" class="data row2 col13" >nan</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row2_col14" class="data row2 col14" >4edbccaaf9abeea3db5268df</td>
#             </tr>
#             <tr>
#                                 <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row3_col0" class="data row3 col0" >Castries Bar & Five Way Restaurant</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row3_col1" class="data row3 col1" >Caribbean Restaurant</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row3_col2" class="data row3 col2" >nan</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row3_col3" class="data row3 col3" >43.654728</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row3_col4" class="data row3 col4" >-79.380928</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row3_col5" class="data row3 col5" >[{'label': 'display', 'lat': 43.654727935791016, 'lng': -79.38092803955078}]</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row3_col6" class="data row3 col6" >177</td>
#                         <td id="T_9e39b890_8b7b_11ea_b717_3699d58e4ce7row3_col7" class="data row3 col7" >nan</td>

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading https://files.pythonhosted.org/packages/95/8c/83563c60489954e5b80f9e2596b93a68e1ac4e4a730deb1aae632066d704/openpyxl-3.0.3.tar.gz (172kB)
#      |████████████████████████████████| 174kB 5.9MB/s eta 0:00:01
# Collecting jdcal (from openpyxl)
#   Downloading https://files.pythonhosted.org/packages/f0/da/572cbc0bc582390480bbd7c4e93d14dc46079778ed915b505dc494b37c57/jdcal-1.4.1-py2.py3-none-any.whl
# Collecting et_xmlfile (from openpyxl)
#   Downloading https://files.pythonhosted.org/packages/22/28/a99c42aea746e18382ad9fb36f64c1c1f04216f41797f2f0fa567da11388/et_xmlfile-1.0.1.tar.gz
# Building wheels for collected packages: openpyxl, et-xmlfile
#   Building wheel for openpyxl (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/b5/85/ca/e768ac132e57e75e645a151f8badac71cc0089e7225dddf76b
#   Building wheel for et-xmlfile (setup.py) ... done
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/2a/77/35/0da0965a057698121fc7d8c5a7a9955cdbfb3cc4e2423cad39
# Successfully built openpyxl et-xmlfile
# Installing collected packages: jdcal, et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.0.1 jdcal-1.4.1 openpyxl-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
sort_by_distance.to_excel ('tableu.xlsx')

# %% [markdown]
# #### Explore Restaurants using their ID

# %%
# Making calls to Foursquare API to get 'given values'
# We then get the Rating, Price, Tier and Currency for others

# %%
venue_id = '4ad7929cf964a520500c21e3' # ID of The Senator Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4ad7929cf964a520500c21e3?client_id=2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH&client_secret=FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']

# To simplify, output was cleared
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'venuePage', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'seasonalHours', 'defaultHours', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4ad7929cf964a520500c21e3',
#  'name': 'The Senator Restaurant',
#  'contact': {'phone': '4163647517',
#   'formattedPhone': '(416) 364-7517',
#   'twitter': 'thesenatorto',
#   'facebook': '566290650069193',
#   'facebookUsername': 'thesenatorto',
#   'facebookName': 'The Senator'},
#  'location': {'address': '249 Victoria Street',
#   'crossStreet': 'btwn Dundas St E and Shuter St',
#   'lat': 43.65564091455335,
#   'lng': -79.37919882575557,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.65564091455335,
#     'lng': -79.37919882575557}],
#   'postalCode': 'M5B 1T8',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#    'Toronto ON M5B 1T8',
#    'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/the-senator-restaurant/4ad7929cf964a520500c21e3',
#  'categories': [{'id': '4bf58dd8d48988d147941735',
#    'name': 'Diner',
#    'pluralName': 'Diners',
#    'shortName': 'Diner',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d143941735',
#    'name': 'Breakfast Spot',
#    'pluralName': 'Breakfast Spots',
#    'shortName': 'Breakfast',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#     'suffix': '.png'}}],
#  'verified': True,
#  'stats': {'tipCount': 96},
#  'url': 'http://www.thesenator.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'likes': {'count': 183,
#   'groups': [{'type': 'others', 'count': 183, 'items': []}],
#   'summary': '183 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.6,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 292,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 218,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 218,
#     'items': [{'id': '507964c4e4b06b24d9da3762',
#       'createdAt': 1350132932,
#       'source': {'name': 'Foursquare for BlackBerry',
#        'url': 'https://foursquare.com/download/#/blackberry'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/5846032_38K6mzPDLCT2DwCU3_mf8JT8AR9nzGeoYTUUCl74Jgc.jpg',
#       'width': 460,
#       'height': 353,
#       'user': {'id': '5846032',
#        'firstName': 'Karen',
#        'lastName': 'M',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-WQCXBSFVPNOVJEZX.jpg'}},
#       'visibility': 'public'}]}]},
#  'venuePage': {'id': '55585058'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': "real food, real good - a history of serving Toronto's best comfort food, heartiest brunch, and new classics. Stop by for a coffee, a meal, or both!",
#  'storeId': '',
#  'page': {'user': {'id': '55585058',
#    'firstName': 'The Senator Restaurant',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/55585058-C0MCLLHHU0GE5SWV.png'},
#    'type': 'venuePage',
#    'venue': {'id': '4ad7929cf964a520500c21e3'},
#    'tips': {'count': 12},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'bio': ''}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1255641756,
#  'tips': {'count': 96,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 96,
#     'items': [{'id': '4d6a9fdc1a88b1f7b3163a5d',
#       'createdAt': 1298833372,
#       'text': "There's free wifi... Password baconandeggs.  :)",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4d6a9fdc1a88b1f7b3163a5d',
#       'lang': 'en',
#       'likes': {'count': 8,
#        'groups': [{'type': 'others',
#          'count': 8,
#          'items': [{'id': '149179920',
#            'firstName': 'Katie',
#            'lastName': 'N',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/149179920-RVB5N3OTNFKATPCI.jpg'}},
#           {'id': '16364197',
#            'firstName': 'Ketellyn',
#            'lastName': 'M',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/16364197-104F1JM24DPPBA3N.jpg'}},
#           {'id': '63765282',
#            'firstName': 'DONNA',
#            'lastName': 'K',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_boy.png',
#             'default': True}},
#           {'id': '12267554',
#            'firstName': 'Ameene',
#            'lastName': 'S',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/12267554-JEQWQULYDQPJUY50.jpg'}}]}],
#        'summary': '8 likes'},
#       'logView': True,
#       'agreeCount': 8,
#       'disagreeCount': 0,
#       'todo': {'count': 1},
#       'user': {'id': '64840',
#        'firstName': 'Rob',
#        'lastName': 'T',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/64840_1257883990432.jpg'}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/6bsOlC',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 179,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 179,
#     'items': [{'id': '4ea08044f790341b16752702',
#       'name': 'Pig Out Sesh',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '6314205',
#        'firstName': 'Stephanie',
#        'lastName': 'D',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/E3KJRGVHZEZ4K5NG.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/6314205/list/pig-out-sesh',
#       'canonicalUrl': 'https://foursquare.com/user/6314205/list/pig-out-sesh',
#       'createdAt': 1319141444,
#       'updatedAt': 1449541060,
#       'photo': {'id': '502c7245e4b0f9a2dbf0b669',
#        'createdAt': 1345090117,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/accSR_DsGPRW2LS3RmWLeN4ONiHAeadgttcrDLZpbtk.jpg',
#        'width': 537,
#        'height': 720,
#        'user': {'id': '6314205',
#         'firstName': 'Stephanie',
#         'lastName': 'D',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/E3KJRGVHZEZ4K5NG.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 32},
#       'listItems': {'count': 76,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1319142227}]}},
#      {'id': '4e99ef0402d5df1b500cc675',
#       'name': 'Bucket',
#       'description': 'Places to GOGOGOGOGO!~',
#       'type': 'others',
#       'user': {'id': '12757451',
#        'firstName': 'Mike',
#        'lastName': 'L',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/W0DNMYCYZ25H2EKR.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/12757451/list/bucket',
#       'canonicalUrl': 'https://foursquare.com/user/12757451/list/bucket',
#       'createdAt': 1318711044,
#       'updatedAt': 1429283379,
#       'photo': {'id': '4ee8eef7722e1234950e5af4',
#        'createdAt': 1323888375,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0BTJ2NT5C3NATQFKNF2Z4QPJQNYU4IX2ZSRGTFIW5OGSCYYJ.jpg',
#        'width': 720,
#        'height': 537,
#        'user': {'id': '1271706',
#         'firstName': 'Samantha',
#         'lastName': 'R',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/PEDCRSHHNGWVDA2Y.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 71},
#       'listItems': {'count': 197,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1318712705}]}},
#      {'id': '50002e60e4b0b435847980b2',
#       'name': 'Hollywood North: Toronto',
#       'description': 'Many movie memories have been created right here in Toronto. We invite you to explore the places and the stories around how they came to life. It’s a great way to see another side of this city.',
#       'type': 'others',
#       'user': {'id': '19644815',
#        'firstName': 'Cineplex',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/V5MQHIBJBQGFGMWH.jpg'},
#        'type': 'chain'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/cineplexmovies/list/hollywood-north-toronto',
#       'canonicalUrl': 'https://foursquare.com/cineplexmovies/list/hollywood-north-toronto',
#       'createdAt': 1342189152,
#       'updatedAt': 1362424862,
#       'photo': {'id': '4fdd398de4b0dd796bb08d55',
#        'createdAt': 1339898253,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/GyeQYaeVQfZn0-HKSTVo4Y4rfSKJNlWYvemq_dGFrZE.jpg',
#        'width': 540,
#        'height': 720,
#        'user': {'id': '2215543',
#         'firstName': 'David',
#         'lastName': 'L',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/-ZTC0XIOQNJI2TXUI.jpg'}},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 45},
#       'listItems': {'count': 16,
#        'items': [{'id': 't5000325be4b03b5b3b48af2e',
#          'createdAt': 1342190037,
#          'photo': {'id': '4f3a6b1ee4b0a4d443a40618',
#           'createdAt': 1329228574,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/vDgYcebQP0BpXYqBkm6UMWwNWzZNiMv1gC_OzQQI7X8.jpg',
#           'width': 537,
#           'height': 720,
#           'user': {'id': '2564098',
#            'firstName': 'Dom',
#            'lastName': 'D',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/G2KSI2FHXJ31DZZT.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4f536f5ae4b092980eec4279',
#       'name': 'Historic Toronto',
#       'description': 'In 1793, Toronto, then known as York, was named capital of the new colony of Upper Canada.',
#       'type': 'others',
#       'user': {'id': '334449',
#        'firstName': 'Sebastian Mark',
#        'lastName': 'K',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/334449-0WCCS0DP2TUXFUBQ.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/bastian_mark/list/historic-toronto',
#       'canonicalUrl': 'https://foursquare.com/bastian_mark/list/historic-toronto',
#       'createdAt': 1330868058,
#       'updatedAt': 1336422774,
#       'photo': {'id': '4f1acf56e4b0b4fde89a7e58',
#        'createdAt': 1327157078,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/3ZR0JOK0P1VUHAKAGHR5XJUX35A1A52W0NBPFIECJZ1KFRLY.jpg',
#        'width': 720,
#        'height': 540,
#        'user': {'id': '12743840',
#         'firstName': 'Hamish',
#         'lastName': 'L',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/01VDXZFHOSIUIO3Q.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 48},
#       'listItems': {'count': 44,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1330870279,
#          'photo': {'id': '4f3a6b1ee4b0a4d443a40618',
#           'createdAt': 1329228574,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/vDgYcebQP0BpXYqBkm6UMWwNWzZNiMv1gC_OzQQI7X8.jpg',
#           'width': 537,
#           'height': 720,
#           'user': {'id': '2564098',
#            'firstName': 'Dom',
#            'lastName': 'D',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/G2KSI2FHXJ31DZZT.jpg'}},
#           'visibility': 'public'}}]}}]}]},
#  'hours': {'status': 'Closed until 7:30 AM',
#   'richStatus': {'entities': [], 'text': 'Closed until 7:30 AM'},
#   'isOpen': False,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon',
#     'open': [{'renderedTime': '7:30 AM–2:30 PM'}],
#     'segments': []},
#    {'days': 'Tue–Fri',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:30 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–2:30 PM'},
#      {'renderedTime': '4:30 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–2:30 PM'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '8:00 AM–2:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–3:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–3:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '9:00 AM–1:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '8:00 AM–1:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Wed–Thu',
#     'open': [{'renderedTime': '8:00 AM–2:00 PM'}],
#     'segments': []}]},
#  'seasonalHours': [],
#  'defaultHours': {'status': 'Closed until 7:30 AM',
#   'richStatus': {'entities': [], 'text': 'Closed until 7:30 AM'},
#   'isOpen': False,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon',
#     'open': [{'renderedTime': '7:30 AM–2:30 PM'}],
#     'segments': []},
#    {'days': 'Tue–Fri',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:30 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–2:30 PM'},
#      {'renderedTime': '4:30 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–2:30 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express & MasterCard)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Free Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Free'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dessert, Lunch & more',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#      {'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Dessert', 'displayValue': 'Dessert'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Full Bar & Cocktails',
#     'count': 5,
#     'items': [{'displayName': 'Full Bar', 'displayValue': 'Full Bar'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'No Delivery'}]}]},
#  'bestPhoto': {'id': '507964c4e4b06b24d9da3762',
#   'createdAt': 1350132932,
#   'source': {'name': 'Foursquare for BlackBerry',
#    'url': 'https://foursquare.com/download/#/blackberry'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/5846032_38K6mzPDLCT2DwCU3_mf8JT8AR9nzGeoYTUUCl74Jgc.jpg',
#   'width': 460,
#   'height': 353,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '507964c4e4b06b24d9da3762',
#    'value': -14673896},
#   'highlightTextColor': {'photoId': '507964c4e4b06b24d9da3762', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.6

# %%
try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
# Out:
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}

# %%
# Now we leverage the Foursquare location data to the fullest
# let's get the Rating, Price, Tier and Currency for other restaurants


venue_id = '4c6abb8c2c29d13ad2720e41' # Subway
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
    
venue_id = '4fbbb3ace4b01e39077b4d55' # Akashiro Japanese Restaurant & Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
        
venue_id = '4edbccaaf9abeea3db5268df' # Terrace Restaurant at Elmwood
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '53ae6660498e1ac3c1282743' # Castries Bar & Five Way Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')

    
venue_id = '56dd9d68498eb4e5edcb30f9' #  Spring Rolls | Japanese Restaurant in Toronto
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '5165c333e4b07a7ad88d8a69' #   Joe's Indian Restaurant 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '4afcc52df964a520b82522e3' #  Donatello Restaurant 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
    
venue_id = '4ae9ef82f964a520cbb721e3' #  Alio Restaurant & Wine Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
    
venue_id = '4ad4c05ff964a52048f720e' # Hemispheres Restaurant & Bistro
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
       
venue_id = '4b2027b5f964a520f82d24e3' #  Hong Shing Chinese Restaurant 
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
# Out:
# 5.6
# {'tier': 1, 'message': 'Cheap', 'currency': '$'}
# 5.6
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# No Details.
# This venue has not been rated yet.
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 7.3
# {'tier': 3, 'message': 'Expensive', 'currency': '$'}
# 5.3
# {'tier': 4, 'message': 'Very Expensive', 'currency': '$'}
# This venue has not been rated yet.
# No Details.
# 6.6
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}

# %% [markdown]
# ##### Dataset Results above were extracted to csv format

# %%
# Let's get the csv file to create new dataframe
df_dtres = pd.read_csv('DT_Res_final.csv')
df_dtres

# %% [markdown]
# ##### New Dataframe: Rating and Price

# %%
# Look for word 'Cheap'
df_word=df_dtres[df_dtres['Price'].str.contains('Cheap')].reset_index(drop=True)

# Hide the index
df_word.style.hide_index()

# %%
# Look for word 'Moderate'
df_word=df_dtres[df_dtres['Price'].str.contains('Moderate')].reset_index(drop=True)

# Hide the index
df_word.style.hide_index()
