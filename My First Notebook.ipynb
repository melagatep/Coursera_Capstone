# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# #### Mel Agatep
# Data Scientist

# %% [markdown]
# *I am interested in data science because there is an abundant of data that needed to be explored and open source software to analyze it.*

# %% [markdown]
# ### Calculate the sum of 1 plus 1

# %%
1+1
# Out:
# 2

# %% [markdown]
# 1. Good
# 2. Evening
#
# * Happy
# * Studying
# * All
#
# | GROCERY       | PRICES        |
# | ------------- |:-------------:|
# | BANANA        | $ 2           |
# | STRAWBERRY    | $ 4           |
#
#
# > *"Yours Truly"* - Mel Agatep
