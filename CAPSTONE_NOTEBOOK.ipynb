# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Second Week / Course Week 5)

# %% [markdown]
# Instructions (The Final Deliverables)
#
# In this week, you will continue working on your capstone project. Please remember by the end of this week, you will need to submit the following:
#
# 1.  A full report consisting of all of the following components (15 marks):
# * Introduction where you discuss the business problem and who would be interested in this project.
# * Data where you describe the data that will be used to solve the problem and the source of the data.
# * Methodology section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, if any, and what machine learnings were used and why.
# * Results section where you discuss the results.
# * Discussion section where you discuss any observations you noted and any recommendations you can make based on the results.
# * Conclusion section where you conclude the report.
#
# 2. A link to your Notebook on your Github repository pushed showing your code. (15 marks)
#
# 3. Your choice of a presentation or blogpost. (10 marks)

# %% [markdown]
# ## TABLE OF CONTENTS

# %% [markdown]
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Discussion](#discussion)
# * [Conclusion](#conclusion)
# <br>
# <br>

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# **Description of the problem:**
#
#   For this data science problem, we will explore on how a "Restaurant Guide App" improve consumer experience by answering the question;
#   Does the two-factor (Rating and Price) approach sufficient to recommend a venue ?
#
# **Target audience description:**
#
#   To help a group of stakeholders further solve the problem, we will address "Cuisine Connoisseurs, Food Enthusiast and Bloggers" who constantly use restaurant guide app for ease of use.
#
# **Discussion on why our Target audience care about the problem:**
#
#  Everything today is accessible by means of smart phones. In the food industry, Cuisine Connoisseurs, Food Enthusiast and Bloggers wants a quick easy way to access venue information. They often want straightforward details without the hassle of too much unnecessary data to influence their decision. Now, how do we improve these experience? Why should they care about the two-factor approach in this data science problem? - The minimalistic comparison data use, which is combining Rating and Price will give our targeted audience better insight in finding great budget-friendly restaurants in downtown areas.
# <br>
# <br>

# %% [markdown]
# ## Data Section <a name="data"></a>

# %% [markdown]
# **Description of the data:**
#
#   The data sets generated in this **Data Section** is to provide insights on our proposed problem. We will focus mainly on Downtown Toronto. First, we will get the Latitude and Longitude value of our approximate defined center, which is the downtown area. We then define a query to search within our desired range and limit for restaurant venues using Foursquare API. Respectively, by making calls to the API, we can get the Restaurant Rating and Price. Using Folium plotting library we can visualize our map of the downtown area.
#
# **Other datasets in combination with the Foursquare location data:**
#
#   We will enter coordinates generated from the API for our downtown area to google maps. In doing so, we can pinpoint an address for our approximate defined center and further test venue location accuracy and other information. Also, in combination with Foursquare location data, a 'csv file' that depict Rating and Price will be created from the dataset results.
#
# **Examples of the data:**
#
# * Foursquare Credentials and Version
# * The geographical coordinate of Downtown Toronto are 43.6563221, -79.3809161.
# * The specific venue category : radius = 500; limit = 10
# * JSON file for our dataframe
# * Venues_map using folium.Map
# * Restaurants IDs using https://api.foursquare.com/v2/venues
#
# **Using Data to solve the problem:**
#
#   With the generated Data, we can make selection of existing restaurant in any category. The map visualization will be use to show the distance of the restaurants within the neighborhood. Part of the JSON file is significant in examining our calls to Foursquare API and to transform our dataframe for analysis. Relatively, making calls to Foursquare location data will get our given values to make our comparison. Eventually, this dataset results will help us solve the question if our two-factor (Rating and Price) approach sufficient to recommend a venue.

# %% [markdown]
# #### Codes <a name="data"></a>

# %% [markdown]
# **Import necessary Libraries:**

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.8.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH' # your Foursquare ID
CLIENT_SECRET = 'FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH
# CLIENT_SECRET:FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS

# %%
# Use geopy library to get the latitude and longitude values of Downtown Toronto

address = 'Downtown Toronto, ON'
geolocator = Nominatim(user_agent="Downtown_Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6563221, -79.3809161.

# %% [markdown]
# <br>
#
# ### The Search for a specific venue

# %% [markdown]
# Imagine our targeted audience (Cuisine Connoisseurs, Food Enthusiast and Bloggers) is in a downtown area using the Restaurant Guide App and wanted to find great budget-friendly restaurants. It is a busy town, a quick comparison of several venues in close proximity would be ideal for they're always on the go.
# <br>

# %%
# define a query to search for Restaurant within 500 metres from Downtown Toronto

search_query = 'Restaurant'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# #### Define the corresponding URL and limit = 10

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH&client_secret=FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS&ll=43.6563221,-79.3809161&v=20180604&query=Restaurant&radius=500&limit=10'

# %% [markdown]
# #### Make the call to foursquare api; send GET Request and examine results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5df88bb86d8c56001bd7d7a2'},
#  'response': {'venues': [{'id': '4ad4c05ff964a52048f720e3',
#     'name': 'Hemispheres Restaurant & Bistro',
#     'location': {'address': '110 Chestnut Street',
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'distance': 434,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '4edbccaaf9abeea3db5268df',
#     'name': 'Terrace Restaurant at Elmwood',
#     'location': {'lat': 43.65610066909799,
#      'lng': -79.38148016065777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610066909799,
#        'lng': -79.38148016065777}],
#      'distance': 51,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '4c6abb8c2c29d13ad2720e41',
#     'name': 'Subway',
#     'location': {'address': '10 Dundas St. E',
#      'crossStreet': 'at Yonge St.',
#      'lat': 43.656259989688905,
#      'lng': -79.38091959903076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656259989688905,
#        'lng': -79.38091959903076}],
#      'distance': 6,
#      'postalCode': 'M5B 2G9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Dundas St. E (at Yonge St.)',
#       'Toronto ON M5B 2G9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '4b295e10f964a520ba9d24e3',
#     'name': 'Richtree Natural Market Restaurants',
#     'location': {'address': '14 Queen St W',
#      'lat': 43.652614361741726,
#      'lng': -79.38023131683906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652614361741726,
#        'lng': -79.38023131683906}],
#      'distance': 416,
#      'postalCode': 'M5H 3X4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['14 Queen St W', 'Toronto ON M5H 3X4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '4b2027b5f964a520f82d24e3',
#     'name': 'Hong Shing Chinese Restaurant',
#     'location': {'address': '195 Dundas St W',
#      'crossStreet': 'at University Ave',
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'distance': 520,
#      'postalCode': 'M5G 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '60327598'},
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '4fbbb3ace4b01e39077b4d55',
#     'name': 'Akashiro Japanese Restaurant & Bar',
#     'location': {'address': '220 Yonge St.',
#      'crossStreet': 'in Toronto Eaton Centre Urban Eatery',
#      'lat': 43.65596504293232,
#      'lng': -79.38054070644233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65596504293232,
#        'lng': -79.38054070644233}],
#      'distance': 49,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '4ad7929cf964a520500c21e3',
#     'name': 'The Senator Restaurant',
#     'location': {'address': '249 Victoria Street',
#      'crossStreet': 'btwn Dundas St E and Shuter St',
#      'lat': 43.65564091455335,
#      'lng': -79.37919882575557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564091455335,
#        'lng': -79.37919882575557}],
#      'distance': 157,
#      'postalCode': 'M5B 1T8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#       'Toronto ON M5B 1T8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '55585058'},
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '53ae6660498e1ac3c1282743',
#     'name': 'Castries Bar & Five Way Restaurant',
#     'location': {'lat': 43.654727935791016,
#      'lng': -79.38092803955078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654727935791016,
#        'lng': -79.38092803955078}],
#      'distance': 177,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '5a8b24b2018cbb6c4ca70dae',
#     'name': 'Hendricks Restaurant & Bar',
#     'location': {'address': 'Yonge And Queen',
#      'lat': 43.65341542752959,
#      'lng': -79.37969842137554,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65341542752959,
#        'lng': -79.37969842137554}],
#      'distance': 338,
#      'postalCode': 'M5G 2H6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Yonge And Queen', 'Toronto ON M5G 2H6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576569799',
#     'hasPerk': False},
#    {'id': '52a7ae41498eed3af4d0a3fa',
#     'name': 'Yueh Tung Chinese Restaurant',
#     'location': {'address': '126 Elizabeth St.',
#      'crossStreet': 'Dundas St.',
#      'lat': 43.655281263429195,
#      'lng': -79.3853365267765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655281263429195,
#        'lng': -79.3853365267765}],
#      'distance': 374,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['126 Elizabeth St. (Dundas St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1576569799',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                 name  \
# 0  4ad4c05ff964a52048f720e3      Hemispheres Restaurant & Bistro
# 1  4edbccaaf9abeea3db5268df        Terrace Restaurant at Elmwood
# 2  4c6abb8c2c29d13ad2720e41                               Subway
# 3  4b295e10f964a520ba9d24e3  Richtree Natural Market Restaurants
# 4  4b2027b5f964a520f82d24e3        Hong Shing Chinese Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1576569799    False
# 1  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1576569799    False
# 2  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...  v-1576569799    False
# 3  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1576569799    False
# 4  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1576569799    False
#
#       location.address  location.lat  location.lng  \
# 0  110 Chestnut Street     43.654884    -79.385931
# 1                  NaN     43.656101    -79.381480
# 2      10 Dundas St. E     43.656260    -79.380920
# 3        14 Queen St W     43.652614    -79.380231
# 4      195 Dundas St W     43.654925    -79.387089
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                434
# 1  [{'label': 'display', 'lat': 43.65610066909799...                 51
# 2  [{'label': 'display', 'lat': 43.65625998968890...                  6
# 3  [{'label': 'display', 'lat': 43.65261436174172...                416
# 4  [{'label': 'display', 'lat': 43.65492521335936...                520
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1                 NaN          CA           NaN            NaN
# 2             M5B 2G9          CA       Toronto             ON
# 3             M5H 3X4          CA       Toronto             ON
# 4             M5G 1C7          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada                                           [Canada]
# 2           Canada  [10 Dundas St. E (at Yonge St.), Toronto ON M5...
# 3           Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 4           Canada  [195 Dundas St W (at University Ave), Toronto ...
#
#   location.crossStreet venuePage.id
# 0                  NaN          NaN
# 1                  NaN          NaN
# 2         at Yonge St.          NaN
# 3                  NaN          NaN
# 4    at University Ave     60327598

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                   name            categories  \
# 0      Hemispheres Restaurant & Bistro   American Restaurant
# 1        Terrace Restaurant at Elmwood   American Restaurant
# 2                               Subway        Sandwich Place
# 3  Richtree Natural Market Restaurants            Restaurant
# 4        Hong Shing Chinese Restaurant    Chinese Restaurant
# 5   Akashiro Japanese Restaurant & Bar      Sushi Restaurant
# 6               The Senator Restaurant                 Diner
# 7   Castries Bar & Five Way Restaurant  Caribbean Restaurant
# 8           Hendricks Restaurant & Bar            Restaurant
# 9         Yueh Tung Chinese Restaurant    Chinese Restaurant
#
#                address        lat        lng  \
# 0  110 Chestnut Street  43.654884 -79.385931
# 1                  NaN  43.656101 -79.381480
# 2      10 Dundas St. E  43.656260 -79.380920
# 3        14 Queen St W  43.652614 -79.380231
# 4      195 Dundas St W  43.654925 -79.387089
# 5        220 Yonge St.  43.655965 -79.380541
# 6  249 Victoria Street  43.655641 -79.379199
# 7                  NaN  43.654728 -79.380928
# 8      Yonge And Queen  43.653415 -79.379698
# 9    126 Elizabeth St.  43.655281 -79.385337
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...       434    M5G 1R3  CA
# 1  [{'label': 'display', 'lat': 43.65610066909799...        51        NaN  CA
# 2  [{'label': 'display', 'lat': 43.65625998968890...         6    M5B 2G9  CA
# 3  [{'label': 'display', 'lat': 43.65261436174172...       416    M5H 3X4  CA
# 4  [{'label': 'display', 'lat': 43.65492521335936...       520    M5G 1C7  CA
# 5  [{'label': 'display', 'lat': 43.65596504293232...        49        NaN  CA
# 6  [{'label': 'display', 'lat': 43.65564091455335...       157    M5B 1T8  CA
# 7  [{'label': 'display', 'lat': 43.65472793579101...       177        NaN  CA
# 8  [{'label': 'display', 'lat': 43.65341542752959...       338    M5G 2H6  CA
# 9  [{'label': 'display', 'lat': 43.65528126342919...       374        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1      NaN   NaN  Canada                                           [Canada]
# 2  Toronto    ON  Canada  [10 Dundas St. E (at Yonge St.), Toronto ON M5...
# 3  Toronto    ON  Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 4  Toronto    ON  Canada  [195 Dundas St W (at University Ave), Toronto ...
# 5  Toronto    ON  Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 6  Toronto    ON  Canada  [249 Victoria Street (btwn Dundas St E and Shu...
# 7      NaN   NaN  Canada                                           [Canada]
# 8  Toronto    ON  Canada      [Yonge And Queen, Toronto ON M5G 2H6, Canada]
# 9  Toronto    ON  Canada  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
#
#                             crossStreet                        id
# 0                                   NaN  4ad4c05ff964a52048f720e3
# 1                                   NaN  4edbccaaf9abeea3db5268df
# 2                          at Yonge St.  4c6abb8c2c29d13ad2720e41
# 3                                   NaN  4b295e10f964a520ba9d24e3
# 4                     at University Ave  4b2027b5f964a520f82d24e3
# 5  in Toronto Eaton Centre Urban Eatery  4fbbb3ace4b01e39077b4d55
# 6        btwn Dundas St E and Shuter St  4ad7929cf964a520500c21e3
# 7                                   NaN  53ae6660498e1ac3c1282743
# 8                                   NaN  5a8b24b2018cbb6c4ca70dae
# 9                            Dundas St.  52a7ae41498eed3af4d0a3fa

# %%
dataframe_filtered.name
# Out:
# 0        Hemispheres Restaurant & Bistro
# 1          Terrace Restaurant at Elmwood
# 2                                 Subway
# 3    Richtree Natural Market Restaurants
# 4          Hong Shing Chinese Restaurant
# 5     Akashiro Japanese Restaurant & Bar
# 6                 The Senator Restaurant
# 7     Castries Bar & Five Way Restaurant
# 8             Hendricks Restaurant & Bar
# 9           Yueh Tung Chinese Restaurant
# Name: name, dtype: object

# %% [markdown]
# <br>
#
# ### Map of The City’s Downtown Area

# %% [markdown]
# Would it be convenient if we could show our targeted audience the map of their search. Also this will show them how far they are from a prospective venue.

# %%
# Let’s locate the approximate center and explore neighboring restaurants
# Zoom in to visualize
# Note: Github may not display map

venues_map = folium.Map(location=[latitude, longitude], zoom_start=10) # generate map centred around 

# add a red circle marker to represent 
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Downtown Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Approximate Defined Center: Google Maps

# %% [markdown]
# We searched cordinate 43.6563221, -79.3809161 for Downtown Toronto in google maps. Result will shows "418 The PATH - Yonge-Dundas Square, Toronto, ON M5B 1R4, Canada". This is our approximate defined center and represented by a red circle marker from the generated map above. Using the result, we can test venue location accuracy and other information.

# %% [markdown]
# #### Dataframe Clean Up

# %%
# Let's sort by distance
sort_by_distance = dataframe_filtered.sort_values('distance')
sort_by_distance
# Out:
#                                   name            categories  \
# 2                               Subway        Sandwich Place
# 5   Akashiro Japanese Restaurant & Bar      Sushi Restaurant
# 1        Terrace Restaurant at Elmwood   American Restaurant
# 6               The Senator Restaurant                 Diner
# 7   Castries Bar & Five Way Restaurant  Caribbean Restaurant
# 8           Hendricks Restaurant & Bar            Restaurant
# 9         Yueh Tung Chinese Restaurant    Chinese Restaurant
# 3  Richtree Natural Market Restaurants            Restaurant
# 0      Hemispheres Restaurant & Bistro   American Restaurant
# 4        Hong Shing Chinese Restaurant    Chinese Restaurant
#
#                address        lat        lng  \
# 2      10 Dundas St. E  43.656260 -79.380920
# 5        220 Yonge St.  43.655965 -79.380541
# 1                  NaN  43.656101 -79.381480
# 6  249 Victoria Street  43.655641 -79.379199
# 7                  NaN  43.654728 -79.380928
# 8      Yonge And Queen  43.653415 -79.379698
# 9    126 Elizabeth St.  43.655281 -79.385337
# 3        14 Queen St W  43.652614 -79.380231
# 0  110 Chestnut Street  43.654884 -79.385931
# 4      195 Dundas St W  43.654925 -79.387089
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 2  [{'label': 'display', 'lat': 43.65625998968890...         6    M5B 2G9  CA
# 5  [{'label': 'display', 'lat': 43.65596504293232...        49        NaN  CA
# 1  [{'label': 'display', 'lat': 43.65610066909799...        51        NaN  CA
# 6  [{'label': 'display', 'lat': 43.65564091455335...       157    M5B 1T8  CA
# 7  [{'label': 'display', 'lat': 43.65472793579101...       177        NaN  CA
# 8  [{'label': 'display', 'lat': 43.65341542752959...       338    M5G 2H6  CA
# 9  [{'label': 'display', 'lat': 43.65528126342919...       374        NaN  CA
# 3  [{'label': 'display', 'lat': 43.65261436174172...       416    M5H 3X4  CA
# 0  [{'label': 'display', 'lat': 43.65488413420439...       434    M5G 1R3  CA
# 4  [{'label': 'display', 'lat': 43.65492521335936...       520    M5G 1C7  CA
#
#       city state country                                   formattedAddress  \
# 2  Toronto    ON  Canada  [10 Dundas St. E (at Yonge St.), Toronto ON M5...
# 5  Toronto    ON  Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 1      NaN   NaN  Canada                                           [Canada]
# 6  Toronto    ON  Canada  [249 Victoria Street (btwn Dundas St E and Shu...
# 7      NaN   NaN  Canada                                           [Canada]
# 8  Toronto    ON  Canada      [Yonge And Queen, Toronto ON M5G 2H6, Canada]
# 9  Toronto    ON  Canada  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 3  Toronto    ON  Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 4  Toronto    ON  Canada  [195 Dundas St W (at University Ave), Toronto ...
#
#                             crossStreet                        id
# 2                          at Yonge St.  4c6abb8c2c29d13ad2720e41
# 5  in Toronto Eaton Centre Urban Eatery  4fbbb3ace4b01e39077b4d55
# 1                                   NaN  4edbccaaf9abeea3db5268df
# 6        btwn Dundas St E and Shuter St  4ad7929cf964a520500c21e3
# 7                                   NaN  53ae6660498e1ac3c1282743
# 8                                   NaN  5a8b24b2018cbb6c4ca70dae
# 9                            Dundas St.  52a7ae41498eed3af4d0a3fa
# 3                                   NaN  4b295e10f964a520ba9d24e3
# 0                                   NaN  4ad4c05ff964a52048f720e3
# 4                     at University Ave  4b2027b5f964a520f82d24e3

# %%
# Hide the index
sort_by_distance.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_b0817e7c_20a3_11ea_87b5_029830759839" ><thead>    <tr>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >categories</th>        <th class="col_heading level0 col2" >address</th>        <th class="col_heading level0 col3" >lat</th>        <th class="col_heading level0 col4" >lng</th>        <th class="col_heading level0 col5" >labeledLatLngs</th>        <th class="col_heading level0 col6" >distance</th>        <th class="col_heading level0 col7" >postalCode</th>        <th class="col_heading level0 col8" >cc</th>        <th class="col_heading level0 col9" >city</th>        <th class="col_heading level0 col10" >state</th>        <th class="col_heading level0 col11" >country</th>        <th class="col_heading level0 col12" >formattedAddress</th>        <th class="col_heading level0 col13" >crossStreet</th>        <th class="col_heading level0 col14" >id</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col0" class="data row0 col0" >Subway</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col1" class="data row0 col1" >Sandwich Place</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col2" class="data row0 col2" >10 Dundas St. E</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col3" class="data row0 col3" >43.6563</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col4" class="data row0 col4" >-79.3809</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col5" class="data row0 col5" >[{'label': 'display', 'lat': 43.656259989688905, 'lng': -79.38091959903076}]</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col6" class="data row0 col6" >6</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col7" class="data row0 col7" >M5B 2G9</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col8" class="data row0 col8" >CA</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col9" class="data row0 col9" >Toronto</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col10" class="data row0 col10" >ON</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col11" class="data row0 col11" >Canada</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col12" class="data row0 col12" >['10 Dundas St. E (at Yonge St.)', 'Toronto ON M5B 2G9', 'Canada']</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col13" class="data row0 col13" >at Yonge St.</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row0_col14" class="data row0 col14" >4c6abb8c2c29d13ad2720e41</td>
#             </tr>
#             <tr>
#                                 <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col0" class="data row1 col0" >Akashiro Japanese Restaurant & Bar</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col1" class="data row1 col1" >Sushi Restaurant</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col2" class="data row1 col2" >220 Yonge St.</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col3" class="data row1 col3" >43.656</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col4" class="data row1 col4" >-79.3805</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col5" class="data row1 col5" >[{'label': 'display', 'lat': 43.65596504293232, 'lng': -79.38054070644233}]</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col6" class="data row1 col6" >49</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col8" class="data row1 col8" >CA</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col9" class="data row1 col9" >Toronto</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col10" class="data row1 col10" >ON</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col11" class="data row1 col11" >Canada</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col12" class="data row1 col12" >['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)', 'Toronto ON', 'Canada']</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col13" class="data row1 col13" >in Toronto Eaton Centre Urban Eatery</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row1_col14" class="data row1 col14" >4fbbb3ace4b01e39077b4d55</td>
#             </tr>
#             <tr>
#                                 <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col0" class="data row2 col0" >Terrace Restaurant at Elmwood</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col1" class="data row2 col1" >American Restaurant</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col3" class="data row2 col3" >43.6561</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col4" class="data row2 col4" >-79.3815</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col5" class="data row2 col5" >[{'label': 'display', 'lat': 43.65610066909799, 'lng': -79.38148016065777}]</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col6" class="data row2 col6" >51</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col7" class="data row2 col7" >nan</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col8" class="data row2 col8" >CA</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col9" class="data row2 col9" >nan</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col11" class="data row2 col11" >Canada</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col12" class="data row2 col12" >['Canada']</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col13" class="data row2 col13" >nan</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row2_col14" class="data row2 col14" >4edbccaaf9abeea3db5268df</td>
#             </tr>
#             <tr>
#                                 <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row3_col0" class="data row3 col0" >The Senator Restaurant</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row3_col1" class="data row3 col1" >Diner</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row3_col2" class="data row3 col2" >249 Victoria Street</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row3_col3" class="data row3 col3" >43.6556</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row3_col4" class="data row3 col4" >-79.3792</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row3_col5" class="data row3 col5" >[{'label': 'display', 'lat': 43.65564091455335, 'lng': -79.37919882575557}]</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row3_col6" class="data row3 col6" >157</td>
#                         <td id="T_b0817e7c_20a3_11ea_87b5_029830759839row3_col7" class="data row3 col7" >M5B 1T8</td>
#                         <td id="

# %% [markdown]
# #### Explore Restaurants using their ID

# %%
# Making calls to Foursquare API to get 'given values'
# The Senator Restaurant would be our pilot call
# We then get the Rating, Price, Tier and Currency for others

# %%
venue_id = '4ad7929cf964a520500c21e3' # ID of The Senator Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4ad7929cf964a520500c21e3?client_id=2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH&client_secret=FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'venuePage', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4ad7929cf964a520500c21e3',
#  'name': 'The Senator Restaurant',
#  'contact': {'phone': '4163647517',
#   'formattedPhone': '(416) 364-7517',
#   'twitter': 'thesenatorto',
#   'facebook': '566290650069193',
#   'facebookUsername': 'thesenatorto',
#   'facebookName': 'The Senator'},
#  'location': {'address': '249 Victoria Street',
#   'crossStreet': 'btwn Dundas St E and Shuter St',
#   'lat': 43.65564091455335,
#   'lng': -79.37919882575557,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.65564091455335,
#     'lng': -79.37919882575557}],
#   'postalCode': 'M5B 1T8',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#    'Toronto ON M5B 1T8',
#    'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/the-senator-restaurant/4ad7929cf964a520500c21e3',
#  'categories': [{'id': '4bf58dd8d48988d147941735',
#    'name': 'Diner',
#    'pluralName': 'Diners',
#    'shortName': 'Diner',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d143941735',
#    'name': 'Breakfast Spot',
#    'pluralName': 'Breakfast Spots',
#    'shortName': 'Breakfast',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#     'suffix': '.png'}}],
#  'verified': True,
#  'stats': {'tipCount': 96},
#  'url': 'http://www.thesenator.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'likes': {'count': 184,
#   'groups': [{'type': 'others', 'count': 184, 'items': []}],
#   'summary': '184 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.9,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 293,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 216,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 216,
#     'items': [{'id': '507964c4e4b06b24d9da3762',
#       'createdAt': 1350132932,
#       'source': {'name': 'Foursquare for BlackBerry',
#        'url': 'https://foursquare.com/download/#/blackberry'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/5846032_38K6mzPDLCT2DwCU3_mf8JT8AR9nzGeoYTUUCl74Jgc.jpg',
#       'width': 460,
#       'height': 353,
#       'user': {'id': '5846032',
#        'firstName': 'Karen',
#        'lastName': 'Macaulay',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-WQCXBSFVPNOVJEZX.jpg'}},
#       'visibility': 'public'}]}]},
#  'venuePage': {'id': '55585058'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': "real food, real good - a history of serving Toronto's best comfort food, heartiest brunch, and new classics. Stop by for a coffee, a meal, or both!",
#  'storeId': '',
#  'page': {'user': {'id': '55585058',
#    'firstName': 'The Senator Restaurant',
#    'gender': 'none',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/55585058-C0MCLLHHU0GE5SWV.png'},
#    'type': 'venuePage',
#    'venue': {'id': '4ad7929cf964a520500c21e3'},
#    'tips': {'count': 12},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'homeCity': 'Toronto, ON',
#    'bio': '',
#    'contact': {'facebook': '566290650069193'}}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1255641756,
#  'tips': {'count': 96,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 96,
#     'items': [{'id': '4d6a9fdc1a88b1f7b3163a5d',
#       'createdAt': 1298833372,
#       'text': "There's free wifi... Password baconandeggs.  :)",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4d6a9fdc1a88b1f7b3163a5d',
#       'lang': 'en',
#       'likes': {'count': 8,
#        'groups': [{'type': 'others',
#          'count': 8,
#          'items': [{'id': '149179920',
#            'firstName': 'Katie',
#            'lastName': 'Nicole',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/149179920-RVB5N3OTNFKATPCI.jpg'}},
#           {'id': '16364197',
#            'firstName': 'Ketellyn',
#            'lastName': 'Manique 🇨🇦',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/16364197-104F1JM24DPPBA3N.jpg'}},
#           {'id': '63765282',
#            'firstName': 'DONNA',
#            'lastName': 'Knight',
#            'gender': 'none',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_boy.png',
#             'default': True}},
#           {'id': '12267554',
#            'firstName': 'Ameene',
#            'lastName': 'Shishakly',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/12267554-JEQWQULYDQPJUY50.jpg'}}]}],
#        'summary': '8 likes'},
#       'logView': True,
#       'agreeCount': 8,
#       'disagreeCount': 0,
#       'todo': {'count': 1},
#       'user': {'id': '64840',
#        'firstName': 'Rob',
#        'lastName': 'Tyrie',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/64840_1257883990432.jpg'}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/6bsOlC',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 178,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 178,
#     'items': [{'id': '4ea08044f790341b16752702',
#       'name': 'Pig Out Sesh',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '6314205',
#        'firstName': 'Stephanie',
#        'lastName': 'Depano',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/E3KJRGVHZEZ4K5NG.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/6314205/list/pig-out-sesh',
#       'canonicalUrl': 'https://foursquare.com/user/6314205/list/pig-out-sesh',
#       'createdAt': 1319141444,
#       'updatedAt': 1449541060,
#       'photo': {'id': '502c7245e4b0f9a2dbf0b669',
#        'createdAt': 1345090117,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/accSR_DsGPRW2LS3RmWLeN4ONiHAeadgttcrDLZpbtk.jpg',
#        'width': 537,
#        'height': 720,
#        'user': {'id': '6314205',
#         'firstName': 'Stephanie',
#         'lastName': 'Depano',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/E3KJRGVHZEZ4K5NG.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 32},
#       'listItems': {'count': 76,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1319142227}]}},
#      {'id': '4e99ef0402d5df1b500cc675',
#       'name': 'Bucket',
#       'description': 'Places to GOGOGOGOGO!~',
#       'type': 'others',
#       'user': {'id': '12757451',
#        'firstName': 'Mike',
#        'lastName': 'L',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/W0DNMYCYZ25H2EKR.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/12757451/list/bucket',
#       'canonicalUrl': 'https://foursquare.com/user/12757451/list/bucket',
#       'createdAt': 1318711044,
#       'updatedAt': 1429283379,
#       'photo': {'id': '4ee8eef7722e1234950e5af4',
#        'createdAt': 1323888375,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0BTJ2NT5C3NATQFKNF2Z4QPJQNYU4IX2ZSRGTFIW5OGSCYYJ.jpg',
#        'width': 720,
#        'height': 537,
#        'user': {'id': '1271706',
#         'firstName': 'Samantha',
#         'lastName': 'Robertson',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/PEDCRSHHNGWVDA2Y.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 70},
#       'listItems': {'count': 197,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1318712705}]}},
#      {'id': '50002e60e4b0b435847980b2',
#       'name': 'Hollywood North: Toronto',
#       'description': 'Many movie memories have been created right here in Toronto. We invite you to explore the places and the stories around how they came to life. It’s a great way to see another side of this city.',
#       'type': 'others',
#       'user': {'id': '19644815',
#        'firstName': 'Cineplex',
#        'gender': 'none',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/V5MQHIBJBQGFGMWH.jpg'},
#        'type': 'chain'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/cineplexmovies/list/hollywood-north-toronto',
#       'canonicalUrl': 'https://foursquare.com/cineplexmovies/list/hollywood-north-toronto',
#       'createdAt': 1342189152,
#       'updatedAt': 1362424862,
#       'photo': {'id': '4fdd398de4b0dd796bb08d55',
#        'createdAt': 1339898253,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/GyeQYaeVQfZn0-HKSTVo4Y4rfSKJNlWYvemq_dGFrZE.jpg',
#        'width': 540,
#        'height': 720,
#        'user': {'id': '2215543',
#         'firstName': 'David',
#         'lastName': 'Loft',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/-ZTC0XIOQNJI2TXUI.jpg'}},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 45},
#       'listItems': {'count': 16,
#        'items': [{'id': 't5000325be4b03b5b3b48af2e',
#          'createdAt': 1342190037,
#          'photo': {'id': '4f3a6b1ee4b0a4d443a40618',
#           'createdAt': 1329228574,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/vDgYcebQP0BpXYqBkm6UMWwNWzZNiMv1gC_OzQQI7X8.jpg',
#           'width': 537,
#           'height': 720,
#           'user': {'id': '2564098',
#            'firstName': 'Dom',
#            'lastName': 'D',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/G2KSI2FHXJ31DZZT.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4f536f5ae4b092980eec4279',
#       'name': 'Historic Toronto',
#       'description': 'In 1793, Toronto, then known as York, was named capital of the new colony of Upper Canada.',
#       'type': 'others',
#       'user': {'id': '334449',
#        'firstName': 'Sebastian Mark',
#        'lastName': 'Kadey',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/334449-0WCCS0DP2TUXFUBQ.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/bastian_mark/list/historic-toronto',
#       'canonicalUrl': 'https://foursquare.com/bastian_mark/list/historic-toronto',
#       'createdAt': 1330868058,
#       'updatedAt': 1336422774,
#       'photo': {'id': '4f1acf56e4b0b4fde89a7e58',
#        'createdAt': 1327157078,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/3ZR0JOK0P1VUHAKAGHR5XJUX35A1A52W0NBPFIECJZ1KFRLY.jpg',
#        'width': 720,
#        'height': 540,
#        'user': {'id': '12743840',
#         'firstName': 'Hamish',
#         'lastName': 'Littin',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/01VDXZFHOSIUIO3Q.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 48},
#       'listItems': {'count': 44,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1330870279,
#          'photo': {'id': '4f3a6b1ee4b0a4d443a40618',
#           'createdAt': 1329228574,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/vDgYcebQP0BpXYqBkm6UMWwNWzZNiMv1gC_OzQQI7X8.jpg',
#           'width': 537,
#           'height': 720,
#           'user': {'id': '2564098',
#            'firstName': 'Dom',
#            'lastName': 'D',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/G2KSI2FHXJ31DZZT.jpg'}},
#           'visibility': 'public'}}]}}]}]},
#  'hours': {'status': 'Closed until 7:30 AM',
#   'richStatus': {'entities': [], 'text': 'Closed until 7:30 AM'},
#   'isOpen': False,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon',
#     'open': [{'renderedTime': '7:30 AM–2:30 PM'}],
#     'segments': []},
#    {'days': 'Tue–Fri',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:30 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–2:30 PM'},
#      {'renderedTime': '4:30 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–2:30 PM'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '8:00 AM–1:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Wed–Thu',
#     'open': [{'renderedTime': '8:00 AM–2:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–2:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–3:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–3:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '9:00 AM–1:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express & MasterCard)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Free Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Free'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dessert, Lunch & more',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#      {'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Dessert', 'displayValue': 'Dessert'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Full Bar & Cocktails',
#     'count': 5,
#     'items': [{'displayName': 'Full Bar', 'displayValue': 'Full Bar'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'No Delivery'}]}]},
#  'bestPhoto': {'id': '507964c4e4b06b24d9da3762',
#   'createdAt': 1350132932,
#   'source': {'name': 'Foursquare for BlackBerry',
#    'url': 'https://foursquare.com/download/#/blackberry'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/5846032_38K6mzPDLCT2DwCU3_mf8JT8AR9nzGeoYTUUCl74Jgc.jpg',
#   'width': 460,
#   'height': 353,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '507964c4e4b06b24d9da3762',
#    'value': -14673896},
#   'highlightTextColor': {'photoId': '507964c4e4b06b24d9da3762', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
# Out:
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}

# %%
# Now we leverage the Foursquare location data to the fullest
# let's get the Rating, Price, Tier and Currency for other restaurants


venue_id = '4c6abb8c2c29d13ad2720e41' # Subway
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
    
venue_id = '4fbbb3ace4b01e39077b4d55' # Akashiro Japanese Restaurant & Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
        
venue_id = '4edbccaaf9abeea3db5268df' # Terrace Restaurant at Elmwood
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '539c6f13498e06f4cc765165' # The Elm Tree Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '5a8b24b2018cbb6c4ca70dae' # Hendricks Restaurant & Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    

venue_id = '4ae4b055f964a520229d21e3' # Kyoto House Japanese Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    

venue_id = '52a7ae41498eed3af4d0a3fa' # Yueh Tung Chinese Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')

venue_id = '4b295e10f964a520ba9d24e3' # Richtree Natural Market Restaurants
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')


venue_id = '4ad4c05ff964a52048f720e' # Hemispheres Restaurant & Bistro
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
# Out:
# 5.7
# {'tier': 1, 'message': 'Cheap', 'currency': '$'}
# 5.4
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 8.3
# No Details.
# 6.1
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 5.9
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 7.8
# {'tier': 1, 'message': 'Cheap', 'currency': '$'}
# 6.2
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# No Details.

# %% [markdown]
# ##### Dataset Results above were extracted to csv format

# %%
# Let's get the csv file to create new dataframe
df_dtres = pd.read_csv('DT_Res_final.csv')
df_dtres
# Out:
#                             Restaurant Rating      Price
# 0                               Subway     5.7     Cheap
# 1   Akashiro Japanese Restaurant & Bar     5.4  Moderate
# 2        Terrace Restaurant at Elmwood      NR  Moderate
# 3               The Senator Restaurant     7.9  Moderate
# 4              The Elm Tree Restaurant     8.3        ND
# 5           Hendricks Restaurant & Bar     6.1  Moderate
# 6      Kyoto House Japanese Restaurant     5.9  Moderate
# 7         Yueh Tung Chinese Restaurant     7.8     Cheap
# 8  Richtree Natural Market Restaurants     6.2  Moderate
# 9      Hemispheres Restaurant & Bistro      NR        ND

# %% [markdown]
# ##### New Dataframe: Rating and Price

# %%
# Look for word 'Cheap'
df_word=df_dtres[df_dtres['Price'].str.contains('Cheap')].reset_index(drop=True)

# Hide the index
df_word.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_b187eb76_20a3_11ea_87b5_029830759839" ><thead>    <tr>        <th class="col_heading level0 col0" >Restaurant</th>        <th class="col_heading level0 col1" >Rating </th>        <th class="col_heading level0 col2" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b187eb76_20a3_11ea_87b5_029830759839row0_col0" class="data row0 col0" >Subway</td>
#                         <td id="T_b187eb76_20a3_11ea_87b5_029830759839row0_col1" class="data row0 col1" >5.7</td>
#                         <td id="T_b187eb76_20a3_11ea_87b5_029830759839row0_col2" class="data row0 col2" >Cheap</td>
#             </tr>
#             <tr>
#                                 <td id="T_b187eb76_20a3_11ea_87b5_029830759839row1_col0" class="data row1 col0" >Yueh Tung Chinese Restaurant</td>
#                         <td id="T_b187eb76_20a3_11ea_87b5_029830759839row1_col1" class="data row1 col1" >7.8</td>
#                         <td id="T_b187eb76_20a3_11ea_87b5_029830759839row1_col2" class="data row1 col2" >Cheap</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Table 1

# %%
# Look for word 'Moderate'
df_word=df_dtres[df_dtres['Price'].str.contains('Moderate')].reset_index(drop=True)

# Hide the index
df_word.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_b189cad6_20a3_11ea_87b5_029830759839" ><thead>    <tr>        <th class="col_heading level0 col0" >Restaurant</th>        <th class="col_heading level0 col1" >Rating </th>        <th class="col_heading level0 col2" >Price</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b189cad6_20a3_11ea_87b5_029830759839row0_col0" class="data row0 col0" >Akashiro Japanese Restaurant & Bar</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row0_col1" class="data row0 col1" >5.4</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row0_col2" class="data row0 col2" >Moderate</td>
#             </tr>
#             <tr>
#                                 <td id="T_b189cad6_20a3_11ea_87b5_029830759839row1_col0" class="data row1 col0" >Terrace Restaurant at Elmwood</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row1_col1" class="data row1 col1" >NR</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row1_col2" class="data row1 col2" >Moderate</td>
#             </tr>
#             <tr>
#                                 <td id="T_b189cad6_20a3_11ea_87b5_029830759839row2_col0" class="data row2 col0" >The Senator Restaurant</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row2_col1" class="data row2 col1" >7.9</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row2_col2" class="data row2 col2" >Moderate</td>
#             </tr>
#             <tr>
#                                 <td id="T_b189cad6_20a3_11ea_87b5_029830759839row3_col0" class="data row3 col0" >Hendricks Restaurant & Bar</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row3_col1" class="data row3 col1" >6.1</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row3_col2" class="data row3 col2" >Moderate</td>
#             </tr>
#             <tr>
#                                 <td id="T_b189cad6_20a3_11ea_87b5_029830759839row4_col0" class="data row4 col0" >Kyoto House Japanese Restaurant</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row4_col1" class="data row4 col1" >5.9</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row4_col2" class="data row4 col2" >Moderate</td>
#             </tr>
#             <tr>
#                                 <td id="T_b189cad6_20a3_11ea_87b5_029830759839row5_col0" class="data row5 col0" >Richtree Natural Market Restaurants</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row5_col1" class="data row5 col1" >6.2</td>
#                         <td id="T_b189cad6_20a3_11ea_87b5_029830759839row5_col2" class="data row5 col2" >Moderate</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Table 2
# <br>
# <br>

# %% [markdown]
# ## Methodology Section <a name="methodology"></a>

# %% [markdown]
# In our Business Problem section, we introduced whether our Restaurant Guide App would be sufficient to recommend a venue focusing only within the Rating and Price. Consequently, from our Data Section, we explained how our datasets were used in solving the business problem. For our **data requirements**, we showed that we need both traditional and non-traditional datasets. Mainly leveraging Foursquare Location Data in conjunction with google maps and 'csv file' created from the dataset results. Relatively from the **collected data**, we have identified all sources and how they were extracted. Thus, providing us with better **understanding and preparation** on how to execute our data science problem. Using data visualization, we have created our **modeling and evaluation** for the Restaurant Guide App (Two-Factor Approach).  We have seen the correlations between cleaning up our unstructured and structured datasets to generate our minimalistic results.
# <br>
# <br>

# %% [markdown]
# ## Analysis Section <a name="analysis"></a>

# %% [markdown]
# Stakeholders had to consider the Two-Factor Approach to improve their consumer experience. However, would the gathered datasets enough to deploy this concept? Simple answer is, yes. Let’s **analyze** the "Restaurant Guide App" (Two-Factor Approach);
# Virtually, Table 1 and 2 shows enough data without overwhelming our targeted audience. Cuisine Connoisseurs, Food Enthusiast and Bloggers, who constantly use restaurant guide app for quick venue information, will appreciate this minimalistic comparison. Stakeholders have to consider the two-factor approach for improvement of consumer experience. Developers then can collaborate and utilize the datasets to come up with ways to show the Tables as part of the app. Sometimes, less can influence significant decisions but not to sacrifice functionality. Here, the Rating and Price is sufficient to recommend a venue. Our tables show us, " Yueh Tung Chinese Restaurant and The Senator Restaurant" as our top picks.
# <br>
# Based on the new dataframe and with less programming, we see the Rating and Price category influenced our decisions. Here, we show that the categories pulled our preferred restaurants in the downtown areas. Again, without being explicit, we can predict a restaurant with virtually has the most complete values across the board be our top picks. Thus, improve consumer experience. We also have relied on the patterns of our sub categories (Cheap and Moderate) to build our statistical model.
# <br>
# <br>

# %% [markdown]
# ## Results Section <a name="results"></a>

# %% [markdown]
# Utilizing all identified sources for our data we can make adjustments to our Two-Factor Approach model upon deployment if needed. Moreover, the predictivenes (virtual comparison) of our model can be fine-tuned using the dataset results.  Stakeholders can benefit from its simplicity to refine known testing outcome. Most importantly, with an improved consumer experience in place, it will open opportunities  for constructive feedback to re-evaluate efficiency of our Restaurant Guide App. As we can virtually  see from the tables, we had analyzed our top picks and answered the main question to the data science problem in our data section.
# <br>
# <br>

# %% [markdown]
# ## Discussion Section <a name="discussion"></a>

# %% [markdown]
# Based on the results, even if we leverage the power of Foursquare Location Data to the fullest, external sources can indeed provide a much adequate visualization. Using basic google map search pinpoint our downtown area and approximately test the distance of our neighborhood restaurants. The spreadsheet manipulation we have created for our new dataframe simplified the dataset results and became grounds for comparison. Realistically provided insights that the Two-Factor Approach (Rating and Price) is sufficient to recommend a venue. As previously mentioned, “Sometimes, less can influence significant decisions but not to sacrifice functionality”. With that in mind, to clean these data is not necessarily mean to disregard parts of dataset result. Every code plays a vital part in providing our targeted audience an improve consumer experience. The minimalistic functional comparison assisted our stakeholders to better understand the impact in developing the Restaurant Guide App. As Data Scientist, it is recommended that all datasets, structured or unstructured should be put in consideration.
# <br>
# <br>

# %% [markdown]
# ## Conclusion Section <a name="discussion"></a>

# %% [markdown]
# Finally, can we deploy the model into practice? Yes, the proprietary "Restaurant Guide App" (Two-Factor Approach) model is predictive. Therefore, can be revaluated, refine adjustments and apply testing to known outcome.  Our model is leverage through the power of Foursquare Location Data and external resources.  Hence, we can solve real world issues pertaining to our  data science problem.  We can now be  more competitive in today’s  market trend by polishing  our dataset to improve consumer experience.
