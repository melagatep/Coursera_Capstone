# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# The following data sets will be generated to provide insights on our proposed business problem:
#
# * Latitude and Longitude values of Downtown Toronto using geopy library
# * Search and Query of number of restaurant and their categories with locations, using Foursquare API
# * Restaurant Rating, Price, Tier and Currency by making calls to Foursquare API
# * Map of the downtown area, using folium plotting library
# * Using basic google map search to visualize approximate cordinate of Downtown Toronto
#
# Factor that will influence our analysis:
#
# * Selection of existing restaurants in any category
# * Distance of restaurants in the neighborhood
# * Approximate defined center, which is the downtown area
# * The Price, Rating and Tier for comparison

# %% [markdown]
# #### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')

# To simplify, output was cleared

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH' # your Foursquare ID
CLIENT_SECRET = 'FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH
# CLIENT_SECRET:FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS

# %%
# Use geopy library to get the latitude and longitude values of Downtown Toronto

address = 'Downtown Toronto, ON'
geolocator = Nominatim(user_agent="Downtown_Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6563221, -79.3809161.

# %% [markdown]
# #### Search for a specific venue category

# %%
# define a query to search for Restaurant within 500 metres from Downtown Toronto

search_query = 'Restaurant'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# #### Define the corresponding URL and limit = 10

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH&client_secret=FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS&ll=43.6563221,-79.3809161&v=20180604&query=Restaurant&radius=500&limit=10'

# %% [markdown]
# #### Make the call to foursquare api; send GET Request and examine results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5def04c6542890001b746e2a'},
#  'response': {'venues': [{'id': '4ad4c05ff964a52048f720e3',
#     'name': 'Hemispheres Restaurant & Bistro',
#     'location': {'address': '110 Chestnut Street',
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'distance': 434,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '4b295e10f964a520ba9d24e3',
#     'name': 'Richtree Natural Market Restaurants',
#     'location': {'address': '14 Queen St W',
#      'lat': 43.652614361741726,
#      'lng': -79.38023131683906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652614361741726,
#        'lng': -79.38023131683906}],
#      'distance': 416,
#      'postalCode': 'M5H 3X4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['14 Queen St W', 'Toronto ON M5H 3X4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '4ad7929cf964a520500c21e3',
#     'name': 'The Senator Restaurant',
#     'location': {'address': '249 Victoria Street',
#      'crossStreet': 'btwn Dundas St E and Shuter St',
#      'lat': 43.65564091455335,
#      'lng': -79.37919882575557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564091455335,
#        'lng': -79.37919882575557}],
#      'distance': 157,
#      'postalCode': 'M5B 1T8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#       'Toronto ON M5B 1T8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '55585058'},
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '4fbbb3ace4b01e39077b4d55',
#     'name': 'Akashiro Japanese Restaurant & Bar',
#     'location': {'address': '220 Yonge St.',
#      'crossStreet': 'in Toronto Eaton Centre Urban Eatery',
#      'lat': 43.65596504293232,
#      'lng': -79.38054070644233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65596504293232,
#        'lng': -79.38054070644233}],
#      'distance': 49,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '4edbccaaf9abeea3db5268df',
#     'name': 'Terrace Restaurant at Elmwood',
#     'location': {'lat': 43.65610066909799,
#      'lng': -79.38148016065777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610066909799,
#        'lng': -79.38148016065777}],
#      'distance': 51,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '4c6abb8c2c29d13ad2720e41',
#     'name': 'Subway',
#     'location': {'address': '10 Dundas St. E',
#      'crossStreet': 'at Yonge St.',
#      'lat': 43.656259989688905,
#      'lng': -79.38091959903076,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656259989688905,
#        'lng': -79.38091959903076}],
#      'distance': 6,
#      'postalCode': 'M5B 2G9',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['10 Dundas St. E (at Yonge St.)',
#       'Toronto ON M5B 2G9',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c5941735',
#       'name': 'Sandwich Place',
#       'pluralName': 'Sandwich Places',
#       'shortName': 'Sandwiches',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '52a7ae41498eed3af4d0a3fa',
#     'name': 'Yueh Tung Chinese Restaurant',
#     'location': {'address': '126 Elizabeth St.',
#      'crossStreet': 'Dundas St.',
#      'lat': 43.655281263429195,
#      'lng': -79.3853365267765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655281263429195,
#        'lng': -79.3853365267765}],
#      'distance': 374,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['126 Elizabeth St. (Dundas St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '4ae4b055f964a520229d21e3',
#     'name': 'Kyoto House Japanese Restaurant',
#     'location': {'address': '143 Dundas St. West',
#      'lat': 43.65538110598594,
#      'lng': -79.38527010094231,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65538110598594,
#        'lng': -79.38527010094231}],
#      'distance': 365,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['143 Dundas St. West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a52070f720e3',
#     'name': 'Adega Restaurant',
#     'location': {'address': '33 Elm St',
#      'crossStreet': 'at Bay St',
#      'lat': 43.65751886446546,
#      'lng': -79.38346181502347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65751886446546,
#        'lng': -79.38346181502347}],
#      'distance': 244,
#      'postalCode': 'M5G 1H1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['33 Elm St (at Bay St)',
#       'Toronto ON M5G 1H1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1575945420',
#     'hasPerk': False},
#    {'id': '4b2027b5f964a520f82d24e3',
#     'name': 'Hong Shing Chinese Restaurant',
#     'location': {'address': '195 Dundas St W',
#      'crossStreet': 'at University Ave',
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'distance': 520,
#      'postalCode': 'M5G 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '60327598'},
#     'referralId': 'v-1575945420',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                 name  \
# 0  4ad4c05ff964a52048f720e3      Hemispheres Restaurant & Bistro
# 1  4b295e10f964a520ba9d24e3  Richtree Natural Market Restaurants
# 2  4ad7929cf964a520500c21e3               The Senator Restaurant
# 3  4fbbb3ace4b01e39077b4d55   Akashiro Japanese Restaurant & Bar
# 4  4edbccaaf9abeea3db5268df        Terrace Restaurant at Elmwood
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1575945420    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1575945420    False
# 2  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...  v-1575945420    False
# 3  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1575945420    False
# 4  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1575945420    False
#
#       location.address  location.lat  location.lng  \
# 0  110 Chestnut Street     43.654884    -79.385931
# 1        14 Queen St W     43.652614    -79.380231
# 2  249 Victoria Street     43.655641    -79.379199
# 3        220 Yonge St.     43.655965    -79.380541
# 4                  NaN     43.656101    -79.381480
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                434
# 1  [{'label': 'display', 'lat': 43.65261436174172...                416
# 2  [{'label': 'display', 'lat': 43.65564091455335...                157
# 3  [{'label': 'display', 'lat': 43.65596504293232...                 49
# 4  [{'label': 'display', 'lat': 43.65610066909799...                 51
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1             M5H 3X4          CA       Toronto             ON
# 2             M5B 1T8          CA       Toronto             ON
# 3                 NaN          CA       Toronto             ON
# 4                 NaN          CA           NaN            NaN
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 2           Canada  [249 Victoria Street (btwn Dundas St E and Shu...
# 3           Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 4           Canada                                           [Canada]
#
#                    location.crossStreet venuePage.id
# 0                                   NaN          NaN
# 1                                   NaN          NaN
# 2        btwn Dundas St E and Shuter St     55585058
# 3  in Toronto Eaton Centre Urban Eatery          NaN
# 4                                   NaN          NaN

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                   name           categories  \
# 0      Hemispheres Restaurant & Bistro  American Restaurant
# 1  Richtree Natural Market Restaurants           Restaurant
# 2               The Senator Restaurant                Diner
# 3   Akashiro Japanese Restaurant & Bar     Sushi Restaurant
# 4        Terrace Restaurant at Elmwood  American Restaurant
# 5                               Subway       Sandwich Place
# 6         Yueh Tung Chinese Restaurant   Chinese Restaurant
# 7      Kyoto House Japanese Restaurant     Sushi Restaurant
# 8                     Adega Restaurant           Restaurant
# 9        Hong Shing Chinese Restaurant   Chinese Restaurant
#
#                address        lat        lng  \
# 0  110 Chestnut Street  43.654884 -79.385931
# 1        14 Queen St W  43.652614 -79.380231
# 2  249 Victoria Street  43.655641 -79.379199
# 3        220 Yonge St.  43.655965 -79.380541
# 4                  NaN  43.656101 -79.381480
# 5      10 Dundas St. E  43.656260 -79.380920
# 6    126 Elizabeth St.  43.655281 -79.385337
# 7  143 Dundas St. West  43.655381 -79.385270
# 8            33 Elm St  43.657519 -79.383462
# 9      195 Dundas St W  43.654925 -79.387089
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...       434    M5G 1R3  CA
# 1  [{'label': 'display', 'lat': 43.65261436174172...       416    M5H 3X4  CA
# 2  [{'label': 'display', 'lat': 43.65564091455335...       157    M5B 1T8  CA
# 3  [{'label': 'display', 'lat': 43.65596504293232...        49        NaN  CA
# 4  [{'label': 'display', 'lat': 43.65610066909799...        51        NaN  CA
# 5  [{'label': 'display', 'lat': 43.65625998968890...         6    M5B 2G9  CA
# 6  [{'label': 'display', 'lat': 43.65528126342919...       374        NaN  CA
# 7  [{'label': 'display', 'lat': 43.65538110598594...       365        NaN  CA
# 8  [{'label': 'display', 'lat': 43.65751886446546...       244    M5G 1H1  CA
# 9  [{'label': 'display', 'lat': 43.65492521335936...       520    M5G 1C7  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  Toronto    ON  Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 2  Toronto    ON  Canada  [249 Victoria Street (btwn Dundas St E and Shu...
# 3  Toronto    ON  Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 4      NaN   NaN  Canada                                           [Canada]
# 5  Toronto    ON  Canada  [10 Dundas St. E (at Yonge St.), Toronto ON M5...
# 6  Toronto    ON  Canada  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 7  Toronto    ON  Canada          [143 Dundas St. West, Toronto ON, Canada]
# 8  Toronto    ON  Canada  [33 Elm St (at Bay St), Toronto ON M5G 1H1, Ca...
# 9  Toronto    ON  Canada  [195 Dundas St W (at University Ave), Toronto ...
#
#                             crossStreet                        id
# 0                                   NaN  4ad4c05ff964a52048f720e3
# 1                                   NaN  4b295e10f964a520ba9d24e3
# 2        btwn Dundas St E and Shuter St  4ad7929cf964a520500c21e3
# 3  in Toronto Eaton Centre Urban Eatery  4fbbb3ace4b01e39077b4d55
# 4                                   NaN  4edbccaaf9abeea3db5268df
# 5                          at Yonge St.  4c6abb8c2c29d13ad2720e41
# 6                            Dundas St.  52a7ae41498eed3af4d0a3fa
# 7                                   NaN  4ae4b055f964a520229d21e3
# 8                             at Bay St  4ad4c060f964a52070f720e3
# 9                     at University Ave  4b2027b5f964a520f82d24e3

# %%
dataframe_filtered.name
# Out:
# 0        Hemispheres Restaurant & Bistro
# 1    Richtree Natural Market Restaurants
# 2                 The Senator Restaurant
# 3     Akashiro Japanese Restaurant & Bar
# 4          Terrace Restaurant at Elmwood
# 5                                 Subway
# 6           Yueh Tung Chinese Restaurant
# 7        Kyoto House Japanese Restaurant
# 8                       Adega Restaurant
# 9          Hong Shing Chinese Restaurant
# Name: name, dtype: object

# %% [markdown]
# #### Generate map of the city’s downtown area

# %%
# Let’s locate the approximate center and explore neighboring restaurants
# Zoom in to visualize

venues_map = folium.Map(location=[latitude, longitude], zoom_start=10) # generate map centred around 

# add a red circle marker to represent 
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Downtown Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Approximate Defined Center: Google Maps

# %%
# We searched cordinate 43.6563221, -79.3809161 for Downtown Toronto
# Result shows "418 The PATH - Yonge-Dundas Square, Toronto, ON M5B 1R4, Canada"
# Represented by a red circle marker from the generated map above
# Note: Github might not display map

# %% [markdown]
# #### Dataframe Clean Up

# %%
# Let's sort by distance
sort_by_distance = dataframe_filtered.sort_values('distance')
sort_by_distance
# Out:
#                                   name           categories  \
# 5                               Subway       Sandwich Place
# 3   Akashiro Japanese Restaurant & Bar     Sushi Restaurant
# 4        Terrace Restaurant at Elmwood  American Restaurant
# 2               The Senator Restaurant                Diner
# 8                     Adega Restaurant           Restaurant
# 7      Kyoto House Japanese Restaurant     Sushi Restaurant
# 6         Yueh Tung Chinese Restaurant   Chinese Restaurant
# 1  Richtree Natural Market Restaurants           Restaurant
# 0      Hemispheres Restaurant & Bistro  American Restaurant
# 9        Hong Shing Chinese Restaurant   Chinese Restaurant
#
#                address        lat        lng  \
# 5      10 Dundas St. E  43.656260 -79.380920
# 3        220 Yonge St.  43.655965 -79.380541
# 4                  NaN  43.656101 -79.381480
# 2  249 Victoria Street  43.655641 -79.379199
# 8            33 Elm St  43.657519 -79.383462
# 7  143 Dundas St. West  43.655381 -79.385270
# 6    126 Elizabeth St.  43.655281 -79.385337
# 1        14 Queen St W  43.652614 -79.380231
# 0  110 Chestnut Street  43.654884 -79.385931
# 9      195 Dundas St W  43.654925 -79.387089
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 5  [{'label': 'display', 'lat': 43.65625998968890...         6    M5B 2G9  CA
# 3  [{'label': 'display', 'lat': 43.65596504293232...        49        NaN  CA
# 4  [{'label': 'display', 'lat': 43.65610066909799...        51        NaN  CA
# 2  [{'label': 'display', 'lat': 43.65564091455335...       157    M5B 1T8  CA
# 8  [{'label': 'display', 'lat': 43.65751886446546...       244    M5G 1H1  CA
# 7  [{'label': 'display', 'lat': 43.65538110598594...       365        NaN  CA
# 6  [{'label': 'display', 'lat': 43.65528126342919...       374        NaN  CA
# 1  [{'label': 'display', 'lat': 43.65261436174172...       416    M5H 3X4  CA
# 0  [{'label': 'display', 'lat': 43.65488413420439...       434    M5G 1R3  CA
# 9  [{'label': 'display', 'lat': 43.65492521335936...       520    M5G 1C7  CA
#
#       city state country                                   formattedAddress  \
# 5  Toronto    ON  Canada  [10 Dundas St. E (at Yonge St.), Toronto ON M5...
# 3  Toronto    ON  Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 4      NaN   NaN  Canada                                           [Canada]
# 2  Toronto    ON  Canada  [249 Victoria Street (btwn Dundas St E and Shu...
# 8  Toronto    ON  Canada  [33 Elm St (at Bay St), Toronto ON M5G 1H1, Ca...
# 7  Toronto    ON  Canada          [143 Dundas St. West, Toronto ON, Canada]
# 6  Toronto    ON  Canada  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 1  Toronto    ON  Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 9  Toronto    ON  Canada  [195 Dundas St W (at University Ave), Toronto ...
#
#                             crossStreet                        id
# 5                          at Yonge St.  4c6abb8c2c29d13ad2720e41
# 3  in Toronto Eaton Centre Urban Eatery  4fbbb3ace4b01e39077b4d55
# 4                                   NaN  4edbccaaf9abeea3db5268df
# 2        btwn Dundas St E and Shuter St  4ad7929cf964a520500c21e3
# 8                             at Bay St  4ad4c060f964a52070f720e3
# 7                                   NaN  4ae4b055f964a520229d21e3
# 6                            Dundas St.  52a7ae41498eed3af4d0a3fa
# 1                                   NaN  4b295e10f964a520ba9d24e3
# 0                                   NaN  4ad4c05ff964a52048f720e3
# 9                     at University Ave  4b2027b5f964a520f82d24e3

# %%
# Hide the index
sort_by_distance.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_f18835b8_1af5_11ea_875e_029830e33458" ><thead>    <tr>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >categories</th>        <th class="col_heading level0 col2" >address</th>        <th class="col_heading level0 col3" >lat</th>        <th class="col_heading level0 col4" >lng</th>        <th class="col_heading level0 col5" >labeledLatLngs</th>        <th class="col_heading level0 col6" >distance</th>        <th class="col_heading level0 col7" >postalCode</th>        <th class="col_heading level0 col8" >cc</th>        <th class="col_heading level0 col9" >city</th>        <th class="col_heading level0 col10" >state</th>        <th class="col_heading level0 col11" >country</th>        <th class="col_heading level0 col12" >formattedAddress</th>        <th class="col_heading level0 col13" >crossStreet</th>        <th class="col_heading level0 col14" >id</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col0" class="data row0 col0" >Subway</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col1" class="data row0 col1" >Sandwich Place</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col2" class="data row0 col2" >10 Dundas St. E</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col3" class="data row0 col3" >43.6563</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col4" class="data row0 col4" >-79.3809</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col5" class="data row0 col5" >[{'label': 'display', 'lat': 43.656259989688905, 'lng': -79.38091959903076}]</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col6" class="data row0 col6" >6</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col7" class="data row0 col7" >M5B 2G9</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col8" class="data row0 col8" >CA</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col9" class="data row0 col9" >Toronto</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col10" class="data row0 col10" >ON</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col11" class="data row0 col11" >Canada</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col12" class="data row0 col12" >['10 Dundas St. E (at Yonge St.)', 'Toronto ON M5B 2G9', 'Canada']</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col13" class="data row0 col13" >at Yonge St.</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row0_col14" class="data row0 col14" >4c6abb8c2c29d13ad2720e41</td>
#             </tr>
#             <tr>
#                                 <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col0" class="data row1 col0" >Akashiro Japanese Restaurant & Bar</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col1" class="data row1 col1" >Sushi Restaurant</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col2" class="data row1 col2" >220 Yonge St.</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col3" class="data row1 col3" >43.656</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col4" class="data row1 col4" >-79.3805</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col5" class="data row1 col5" >[{'label': 'display', 'lat': 43.65596504293232, 'lng': -79.38054070644233}]</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col6" class="data row1 col6" >49</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col8" class="data row1 col8" >CA</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col9" class="data row1 col9" >Toronto</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col10" class="data row1 col10" >ON</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col11" class="data row1 col11" >Canada</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col12" class="data row1 col12" >['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)', 'Toronto ON', 'Canada']</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col13" class="data row1 col13" >in Toronto Eaton Centre Urban Eatery</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row1_col14" class="data row1 col14" >4fbbb3ace4b01e39077b4d55</td>
#             </tr>
#             <tr>
#                                 <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col0" class="data row2 col0" >Terrace Restaurant at Elmwood</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col1" class="data row2 col1" >American Restaurant</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col3" class="data row2 col3" >43.6561</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col4" class="data row2 col4" >-79.3815</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col5" class="data row2 col5" >[{'label': 'display', 'lat': 43.65610066909799, 'lng': -79.38148016065777}]</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col6" class="data row2 col6" >51</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col7" class="data row2 col7" >nan</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col8" class="data row2 col8" >CA</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col9" class="data row2 col9" >nan</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col11" class="data row2 col11" >Canada</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col12" class="data row2 col12" >['Canada']</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col13" class="data row2 col13" >nan</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row2_col14" class="data row2 col14" >4edbccaaf9abeea3db5268df</td>
#             </tr>
#             <tr>
#                                 <td id="T_f18835b8_1af5_11ea_875e_029830e33458row3_col0" class="data row3 col0" >The Senator Restaurant</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row3_col1" class="data row3 col1" >Diner</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row3_col2" class="data row3 col2" >249 Victoria Street</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row3_col3" class="data row3 col3" >43.6556</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row3_col4" class="data row3 col4" >-79.3792</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row3_col5" class="data row3 col5" >[{'label': 'display', 'lat': 43.65564091455335, 'lng': -79.37919882575557}]</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row3_col6" class="data row3 col6" >157</td>
#                         <td id="T_f18835b8_1af5_11ea_875e_029830e33458row3_col7" class="data row3 col7" >M5B 1T8</td>
#                         <td id="

# %% [markdown]
# #### Explore Restaurants using their ID

# %%
# Making calls to Foursquare API to get 'given values'
# The Senator Restaurant would be our pilot call
# We then get the Rating, Price, Tier and Currency for others

# %%
venue_id = '4ad7929cf964a520500c21e3' # ID of The Senator Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4ad7929cf964a520500c21e3?client_id=2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH&client_secret=FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'venuePage', 'reasons', 'description', 'storeId', 'page', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4ad7929cf964a520500c21e3',
#  'name': 'The Senator Restaurant',
#  'contact': {'phone': '4163647517',
#   'formattedPhone': '(416) 364-7517',
#   'twitter': 'thesenatorto',
#   'facebook': '566290650069193',
#   'facebookUsername': 'thesenatorto',
#   'facebookName': 'The Senator'},
#  'location': {'address': '249 Victoria Street',
#   'crossStreet': 'btwn Dundas St E and Shuter St',
#   'lat': 43.65564091455335,
#   'lng': -79.37919882575557,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.65564091455335,
#     'lng': -79.37919882575557}],
#   'postalCode': 'M5B 1T8',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#    'Toronto ON M5B 1T8',
#    'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/the-senator-restaurant/4ad7929cf964a520500c21e3',
#  'categories': [{'id': '4bf58dd8d48988d147941735',
#    'name': 'Diner',
#    'pluralName': 'Diners',
#    'shortName': 'Diner',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#     'suffix': '.png'},
#    'primary': True},
#   {'id': '4bf58dd8d48988d143941735',
#    'name': 'Breakfast Spot',
#    'pluralName': 'Breakfast Spots',
#    'shortName': 'Breakfast',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#     'suffix': '.png'}}],
#  'verified': True,
#  'stats': {'tipCount': 96},
#  'url': 'http://www.thesenator.com',
#  'price': {'tier': 2, 'message': 'Moderate', 'currency': '$'},
#  'likes': {'count': 184,
#   'groups': [{'type': 'others', 'count': 184, 'items': []}],
#   'summary': '184 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.9,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 293,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 216,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 216,
#     'items': [{'id': '507964c4e4b06b24d9da3762',
#       'createdAt': 1350132932,
#       'source': {'name': 'Foursquare for BlackBerry',
#        'url': 'https://foursquare.com/download/#/blackberry'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/5846032_38K6mzPDLCT2DwCU3_mf8JT8AR9nzGeoYTUUCl74Jgc.jpg',
#       'width': 460,
#       'height': 353,
#       'user': {'id': '5846032',
#        'firstName': 'Karen',
#        'lastName': 'Macaulay',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/-WQCXBSFVPNOVJEZX.jpg'}},
#       'visibility': 'public'}]}]},
#  'venuePage': {'id': '55585058'},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'description': "real food, real good - a history of serving Toronto's best comfort food, heartiest brunch, and new classics. Stop by for a coffee, a meal, or both!",
#  'storeId': '',
#  'page': {'user': {'id': '55585058',
#    'firstName': 'The Senator Restaurant',
#    'gender': 'none',
#    'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#     'suffix': '/55585058-C0MCLLHHU0GE5SWV.png'},
#    'type': 'venuePage',
#    'venue': {'id': '4ad7929cf964a520500c21e3'},
#    'tips': {'count': 12},
#    'lists': {'groups': [{'type': 'created', 'count': 2, 'items': []}]},
#    'homeCity': 'Toronto, ON',
#    'bio': '',
#    'contact': {'facebook': '566290650069193'}}},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1255641756,
#  'tips': {'count': 96,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 96,
#     'items': [{'id': '4d6a9fdc1a88b1f7b3163a5d',
#       'createdAt': 1298833372,
#       'text': "There's free wifi... Password baconandeggs.  :)",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/4d6a9fdc1a88b1f7b3163a5d',
#       'lang': 'en',
#       'likes': {'count': 8,
#        'groups': [{'type': 'others',
#          'count': 8,
#          'items': [{'id': '149179920',
#            'firstName': 'Katie',
#            'lastName': 'Nicole',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/149179920-RVB5N3OTNFKATPCI.jpg'}},
#           {'id': '16364197',
#            'firstName': 'Ketellyn',
#            'lastName': 'Manique 🇨🇦',
#            'gender': 'female',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/16364197-104F1JM24DPPBA3N.jpg'}},
#           {'id': '63765282',
#            'firstName': 'DONNA',
#            'lastName': 'Knight',
#            'gender': 'none',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/blank_boy.png',
#             'default': True}},
#           {'id': '12267554',
#            'firstName': 'Ameene',
#            'lastName': 'Shishakly',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/12267554-JEQWQULYDQPJUY50.jpg'}}]}],
#        'summary': '8 likes'},
#       'logView': True,
#       'agreeCount': 8,
#       'disagreeCount': 0,
#       'todo': {'count': 1},
#       'user': {'id': '64840',
#        'firstName': 'Rob',
#        'lastName': 'Tyrie',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/64840_1257883990432.jpg'}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/6bsOlC',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 178,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 178,
#     'items': [{'id': '4ea08044f790341b16752702',
#       'name': 'Pig Out Sesh',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '6314205',
#        'firstName': 'Stephanie',
#        'lastName': 'Depano',
#        'gender': 'female',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/E3KJRGVHZEZ4K5NG.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/6314205/list/pig-out-sesh',
#       'canonicalUrl': 'https://foursquare.com/user/6314205/list/pig-out-sesh',
#       'createdAt': 1319141444,
#       'updatedAt': 1449541060,
#       'photo': {'id': '502c7245e4b0f9a2dbf0b669',
#        'createdAt': 1345090117,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/accSR_DsGPRW2LS3RmWLeN4ONiHAeadgttcrDLZpbtk.jpg',
#        'width': 537,
#        'height': 720,
#        'user': {'id': '6314205',
#         'firstName': 'Stephanie',
#         'lastName': 'Depano',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/E3KJRGVHZEZ4K5NG.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 32},
#       'listItems': {'count': 76,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1319142227}]}},
#      {'id': '4e99ef0402d5df1b500cc675',
#       'name': 'Bucket',
#       'description': 'Places to GOGOGOGOGO!~',
#       'type': 'others',
#       'user': {'id': '12757451',
#        'firstName': 'Mike',
#        'lastName': 'L',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/W0DNMYCYZ25H2EKR.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/12757451/list/bucket',
#       'canonicalUrl': 'https://foursquare.com/user/12757451/list/bucket',
#       'createdAt': 1318711044,
#       'updatedAt': 1429283379,
#       'photo': {'id': '4ee8eef7722e1234950e5af4',
#        'createdAt': 1323888375,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/0BTJ2NT5C3NATQFKNF2Z4QPJQNYU4IX2ZSRGTFIW5OGSCYYJ.jpg',
#        'width': 720,
#        'height': 537,
#        'user': {'id': '1271706',
#         'firstName': 'Samantha',
#         'lastName': 'Robertson',
#         'gender': 'female',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/PEDCRSHHNGWVDA2Y.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 70},
#       'listItems': {'count': 197,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1318712705}]}},
#      {'id': '50002e60e4b0b435847980b2',
#       'name': 'Hollywood North: Toronto',
#       'description': 'Many movie memories have been created right here in Toronto. We invite you to explore the places and the stories around how they came to life. It’s a great way to see another side of this city.',
#       'type': 'others',
#       'user': {'id': '19644815',
#        'firstName': 'Cineplex',
#        'gender': 'none',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/V5MQHIBJBQGFGMWH.jpg'},
#        'type': 'chain'},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/cineplexmovies/list/hollywood-north-toronto',
#       'canonicalUrl': 'https://foursquare.com/cineplexmovies/list/hollywood-north-toronto',
#       'createdAt': 1342189152,
#       'updatedAt': 1362424862,
#       'photo': {'id': '4fdd398de4b0dd796bb08d55',
#        'createdAt': 1339898253,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/GyeQYaeVQfZn0-HKSTVo4Y4rfSKJNlWYvemq_dGFrZE.jpg',
#        'width': 540,
#        'height': 720,
#        'user': {'id': '2215543',
#         'firstName': 'David',
#         'lastName': 'Loft',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/-ZTC0XIOQNJI2TXUI.jpg'}},
#        'visibility': 'public'},
#       'logView': True,
#       'followers': {'count': 45},
#       'listItems': {'count': 16,
#        'items': [{'id': 't5000325be4b03b5b3b48af2e',
#          'createdAt': 1342190037,
#          'photo': {'id': '4f3a6b1ee4b0a4d443a40618',
#           'createdAt': 1329228574,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/vDgYcebQP0BpXYqBkm6UMWwNWzZNiMv1gC_OzQQI7X8.jpg',
#           'width': 537,
#           'height': 720,
#           'user': {'id': '2564098',
#            'firstName': 'Dom',
#            'lastName': 'D',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/G2KSI2FHXJ31DZZT.jpg'}},
#           'visibility': 'public'}}]}},
#      {'id': '4f536f5ae4b092980eec4279',
#       'name': 'Historic Toronto',
#       'description': 'In 1793, Toronto, then known as York, was named capital of the new colony of Upper Canada.',
#       'type': 'others',
#       'user': {'id': '334449',
#        'firstName': 'Sebastian Mark',
#        'lastName': 'Kadey',
#        'gender': 'male',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/334449-0WCCS0DP2TUXFUBQ.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': True,
#       'url': '/bastian_mark/list/historic-toronto',
#       'canonicalUrl': 'https://foursquare.com/bastian_mark/list/historic-toronto',
#       'createdAt': 1330868058,
#       'updatedAt': 1336422774,
#       'photo': {'id': '4f1acf56e4b0b4fde89a7e58',
#        'createdAt': 1327157078,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/3ZR0JOK0P1VUHAKAGHR5XJUX35A1A52W0NBPFIECJZ1KFRLY.jpg',
#        'width': 720,
#        'height': 540,
#        'user': {'id': '12743840',
#         'firstName': 'Hamish',
#         'lastName': 'Littin',
#         'gender': 'male',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/01VDXZFHOSIUIO3Q.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 48},
#       'listItems': {'count': 44,
#        'items': [{'id': 'v4ad7929cf964a520500c21e3',
#          'createdAt': 1330870279,
#          'photo': {'id': '4f3a6b1ee4b0a4d443a40618',
#           'createdAt': 1329228574,
#           'prefix': 'https://fastly.4sqi.net/img/general/',
#           'suffix': '/vDgYcebQP0BpXYqBkm6UMWwNWzZNiMv1gC_OzQQI7X8.jpg',
#           'width': 537,
#           'height': 720,
#           'user': {'id': '2564098',
#            'firstName': 'Dom',
#            'lastName': 'D',
#            'gender': 'male',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/G2KSI2FHXJ31DZZT.jpg'}},
#           'visibility': 'public'}}]}}]}]},
#  'hours': {'status': 'Closed until 7:30 AM tomorrow',
#   'richStatus': {'entities': [], 'text': 'Closed until 7:30 AM tomorrow'},
#   'isOpen': False,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:30 AM–2:30 PM'}],
#     'segments': []},
#    {'days': 'Tue–Fri',
#     'open': [{'renderedTime': '7:30 AM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–2:30 PM'},
#      {'renderedTime': '4:30 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–2:30 PM'}],
#     'segments': []}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '9:00 AM–1:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '8:00 AM–1:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Wed–Thu',
#     'open': [{'renderedTime': '8:00 AM–2:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–2:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '8:00 AM–3:00 PM'},
#      {'renderedTime': '6:00 PM–7:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '8:00 AM–3:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$$', 'priceTier': 2}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards',
#       'displayValue': 'Yes (incl. American Express & MasterCard)'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'summary': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'Yes'}]},
#    {'type': 'wifi',
#     'name': 'Wi-Fi',
#     'summary': 'Free Wi-Fi',
#     'count': 1,
#     'items': [{'displayName': 'Wi-Fi', 'displayValue': 'Free'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dessert, Lunch & more',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#      {'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'},
#      {'displayName': 'Dessert', 'displayValue': 'Dessert'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Full Bar & Cocktails',
#     'count': 5,
#     'items': [{'displayName': 'Full Bar', 'displayValue': 'Full Bar'},
#      {'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'No Delivery'}]}]},
#  'bestPhoto': {'id': '507964c4e4b06b24d9da3762',
#   'createdAt': 1350132932,
#   'source': {'name': 'Foursquare for BlackBerry',
#    'url': 'https://foursquare.com/download/#/blackberry'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/5846032_38K6mzPDLCT2DwCU3_mf8JT8AR9nzGeoYTUUCl74Jgc.jpg',
#   'width': 460,
#   'height': 353,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '507964c4e4b06b24d9da3762',
#    'value': -14673896},
#   'highlightTextColor': {'photoId': '507964c4e4b06b24d9da3762', 'value': -1},
#   'algoVersion': 3}}

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
# Out:
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}

# %%
# Now we leverage the Foursquare location data to the fullest and provide insights on our proposed business problem
# let's get the Rating, Price, Tier and Currency for other restaurants


venue_id = '4c6abb8c2c29d13ad2720e41' # Subway
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
    
venue_id = '4fbbb3ace4b01e39077b4d55' # Akashiro Japanese Restaurant & Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
        
venue_id = '4edbccaaf9abeea3db5268df' # Terrace Restaurant at Elmwood
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '539c6f13498e06f4cc765165' # The Elm Tree Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '5a8b24b2018cbb6c4ca70dae' # Hendricks Restaurant & Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    

venue_id = '4ae4b055f964a520229d21e3' # Kyoto House Japanese Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    

venue_id = '52a7ae41498eed3af4d0a3fa' # Yueh Tung Chinese Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')

venue_id = '4b295e10f964a520ba9d24e3' # Richtree Natural Market Restaurants
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')


venue_id = '4ad4c05ff964a52048f720e' # Hemispheres Restaurant & Bistro
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
# Out:
# 5.7
# {'tier': 1, 'message': 'Cheap', 'currency': '$'}
# 5.4
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 8.3
# No Details.
# 6.1
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 5.9
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 7.8
# {'tier': 1, 'message': 'Cheap', 'currency': '$'}
# 6.2
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# No Details.

# %% [markdown]
# ##### Dataset Results above were extracted to csv format

# %%
# Let's get the csv file to create new dataframe
df_dtres = pd.read_csv('DT Toronto Restaurant.csv')

# Display all 10 Restaurants
df_dtres.head(11)

# Hide the index
df_dtres.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_f2f7e286_1af5_11ea_875e_029830e33458" ><thead>    <tr>        <th class="col_heading level0 col0" >Restaurant</th>        <th class="col_heading level0 col1" >ID</th>        <th class="col_heading level0 col2" >Rating </th>        <th class="col_heading level0 col3" >Price</th>        <th class="col_heading level0 col4" >Currency</th>        <th class="col_heading level0 col5" >Tier </th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row0_col0" class="data row0 col0" >Subway</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row0_col1" class="data row0 col1" >4c6abb8c2c29d13ad2720e41</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row0_col2" class="data row0 col2" >5.7</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row0_col3" class="data row0 col3" >Cheap</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row0_col4" class="data row0 col4" >$</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row0_col5" class="data row0 col5" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row1_col0" class="data row1 col0" >Akashiro Japanese Restaurant & Bar</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row1_col1" class="data row1 col1" >4fbbb3ace4b01e39077b4d55</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row1_col2" class="data row1 col2" >5.4</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row1_col3" class="data row1 col3" >Moderate</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row1_col4" class="data row1 col4" >$</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row1_col5" class="data row1 col5" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row2_col0" class="data row2 col0" >Terrace Restaurant at Elmwood</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row2_col1" class="data row2 col1" >4edbccaaf9abeea3db5268df</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row2_col2" class="data row2 col2" >NR</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row2_col3" class="data row2 col3" >Moderate</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row2_col4" class="data row2 col4" >$</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row2_col5" class="data row2 col5" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row3_col0" class="data row3 col0" >The Senator Restaurant</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row3_col1" class="data row3 col1" >4ad7929cf964a520500c21e3</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row3_col2" class="data row3 col2" >7.9</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row3_col3" class="data row3 col3" >Moderate</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row3_col4" class="data row3 col4" >$</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row3_col5" class="data row3 col5" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row4_col0" class="data row4 col0" >The Elm Tree Restaurant</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row4_col1" class="data row4 col1" >539c6f13498e06f4cc765165</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row4_col2" class="data row4 col2" >8.3</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row4_col3" class="data row4 col3" >ND</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row4_col4" class="data row4 col4" >ND</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row4_col5" class="data row4 col5" >ND</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row5_col0" class="data row5 col0" >Hendricks Restaurant & Bar</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row5_col1" class="data row5 col1" >5a8b24b2018cbb6c4ca70dae</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row5_col2" class="data row5 col2" >6.1</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row5_col3" class="data row5 col3" >Moderate</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row5_col4" class="data row5 col4" >$</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row5_col5" class="data row5 col5" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row6_col0" class="data row6 col0" >Kyoto House Japanese Restaurant</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row6_col1" class="data row6 col1" >4ae4b055f964a520229d21e3</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row6_col2" class="data row6 col2" >5.9</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row6_col3" class="data row6 col3" >Moderate</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row6_col4" class="data row6 col4" >$</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row6_col5" class="data row6 col5" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row7_col0" class="data row7 col0" >Yueh Tung Chinese Restaurant</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row7_col1" class="data row7 col1" >52a7ae41498eed3af4d0a3fa</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row7_col2" class="data row7 col2" >7.8</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row7_col3" class="data row7 col3" >Cheap</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row7_col4" class="data row7 col4" >$</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row7_col5" class="data row7 col5" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row8_col0" class="data row8 col0" >Richtree Natural Market Restaurants</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row8_col1" class="data row8 col1" >4b295e10f964a520ba9d24e3</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row8_col2" class="data row8 col2" >6.2</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row8_col3" class="data row8 col3" >Moderate</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row8_col4" class="data row8 col4" >$</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row8_col5" class="data row8 col5" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row9_col0" class="data row9 col0" >Hemispheres Restaurant & Bistro</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row9_col1" class="data row9 col1" >4ad4c05ff964a52048f720e</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row9_col2" class="data row9 col2" >NR</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e33458row9_col3" class="data row9 col3" >ND</td>
#                         <td id="T_f2f7e286_1af5_11ea_875e_029830e3345

# %% [markdown]
# ##### New Dataframe: Price and Rating

# %%
# Drop ID column
df_dtres.drop('ID',axis=1,inplace=True)

# Look for word 'Cheap'
df_word=df_dtres[df_dtres['Price'].str.contains('Cheap')].reset_index(drop=True)


# Hide the index
df_word.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_f2fa4b70_1af5_11ea_875e_029830e33458" ><thead>    <tr>        <th class="col_heading level0 col0" >Restaurant</th>        <th class="col_heading level0 col1" >Rating </th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Currency</th>        <th class="col_heading level0 col4" >Tier </th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row0_col0" class="data row0 col0" >Subway</td>
#                         <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row0_col1" class="data row0 col1" >5.7</td>
#                         <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row0_col2" class="data row0 col2" >Cheap</td>
#                         <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row0_col3" class="data row0 col3" >$</td>
#                         <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row0_col4" class="data row0 col4" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row1_col0" class="data row1 col0" >Yueh Tung Chinese Restaurant</td>
#                         <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row1_col1" class="data row1 col1" >7.8</td>
#                         <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row1_col2" class="data row1 col2" >Cheap</td>
#                         <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row1_col3" class="data row1 col3" >$</td>
#                         <td id="T_f2fa4b70_1af5_11ea_875e_029830e33458row1_col4" class="data row1 col4" >1</td>
#             </tr>
#     </tbody></table>

# %%
# Look for word 'Moderate'
df_word=df_dtres[df_dtres['Price'].str.contains('Moderate')].reset_index(drop=True)


# Hide the index
df_word.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_f2fbd63e_1af5_11ea_875e_029830e33458" ><thead>    <tr>        <th class="col_heading level0 col0" >Restaurant</th>        <th class="col_heading level0 col1" >Rating </th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Currency</th>        <th class="col_heading level0 col4" >Tier </th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row0_col0" class="data row0 col0" >Akashiro Japanese Restaurant & Bar</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row0_col1" class="data row0 col1" >5.4</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row0_col2" class="data row0 col2" >Moderate</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row0_col3" class="data row0 col3" >$</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row0_col4" class="data row0 col4" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row1_col0" class="data row1 col0" >Terrace Restaurant at Elmwood</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row1_col1" class="data row1 col1" >NR</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row1_col2" class="data row1 col2" >Moderate</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row1_col3" class="data row1 col3" >$</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row1_col4" class="data row1 col4" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row2_col0" class="data row2 col0" >The Senator Restaurant</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row2_col1" class="data row2 col1" >7.9</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row2_col2" class="data row2 col2" >Moderate</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row2_col3" class="data row2 col3" >$</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row2_col4" class="data row2 col4" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row3_col0" class="data row3 col0" >Hendricks Restaurant & Bar</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row3_col1" class="data row3 col1" >6.1</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row3_col2" class="data row3 col2" >Moderate</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row3_col3" class="data row3 col3" >$</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row3_col4" class="data row3 col4" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row4_col0" class="data row4 col0" >Kyoto House Japanese Restaurant</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row4_col1" class="data row4 col1" >5.9</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row4_col2" class="data row4 col2" >Moderate</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row4_col3" class="data row4 col3" >$</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row4_col4" class="data row4 col4" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row5_col0" class="data row5 col0" >Richtree Natural Market Restaurants</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row5_col1" class="data row5 col1" >6.2</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row5_col2" class="data row5 col2" >Moderate</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row5_col3" class="data row5 col3" >$</td>
#                         <td id="T_f2fbd63e_1af5_11ea_875e_029830e33458row5_col4" class="data row5 col4" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ##### Top picks by Price and Rating: Yueh Tung Chinese Restaurant and The Senator Restaurant

# %% [markdown]
# #### Final Deliverables

# %% [markdown]
# In Week 2, we will cover:
# * Components: Methodology, Analysis, Results and Discussion, Conclusion
# * Full Report with Components and Presentation
