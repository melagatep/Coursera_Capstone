# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# The following data sets will be generated to provide insights on our proposed business problem:
#
# * Latitude and Longitude values of Downtown Toronto using geopy library
# * Search and Query of number of restaurant and their categories with locations, using Foursquare API
# * Restaurant Rating, Price, Tier and Currency by making calls to Foursquare API
# * Map of the downtown area, using folium plotting library
# * Using basic google map search to visualize approximate cordinate of Downtown Toronto
#
# Factor that will influence our analysis:
#
# * Selection of existing restaurants in any category
# * Distance of restaurants in the neighborhood
# * Approximate defined center, which is the downtown area
# * The Price, Rating and Tier for comparison

# %% [markdown]
# #### Import necessary Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')

# To simplify, output was cleared

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH' # your Foursquare ID
CLIENT_SECRET = 'FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 10
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH
# CLIENT_SECRET:FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS

# %%
# Use geopy library to get the latitude and longitude values of Downtown Toronto

address = 'Downtown Toronto, ON'
geolocator = Nominatim(user_agent="Downtown_Toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Downtown Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Downtown Toronto are 43.6563221, -79.3809161.

# %% [markdown]
# #### Search for a specific venue category

# %%
# define a query to search for Restaurant within 500 metres from Downtown Toronto

search_query = 'Restaurant'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Restaurant .... OK!

# %% [markdown]
# #### Define the corresponding URL and limit = 10

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH&client_secret=FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS&ll=43.6563221,-79.3809161&v=20180604&query=Restaurant&radius=500&limit=10'

# %% [markdown]
# #### Make the call to foursquare api; send GET Request and examine results

# %%
results = requests.get(url).json()
results

# To simplify, output was cleared

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                 name  \
# 0  4ad4c05ff964a52048f720e3      Hemispheres Restaurant & Bistro
# 1  4b295e10f964a520ba9d24e3  Richtree Natural Market Restaurants
# 2  4edbccaaf9abeea3db5268df        Terrace Restaurant at Elmwood
# 3  4fbbb3ace4b01e39077b4d55   Akashiro Japanese Restaurant & Bar
# 4  4ad7929cf964a520500c21e3               The Senator Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1575952267    False
# 1  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1575952267    False
# 2  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...  v-1575952267    False
# 3  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...  v-1575952267    False
# 4  [{'id': '4bf58dd8d48988d147941735', 'name': 'D...  v-1575952267    False
#
#       location.address  location.lat  location.lng  \
# 0  110 Chestnut Street     43.654884    -79.385931
# 1        14 Queen St W     43.652614    -79.380231
# 2                  NaN     43.656101    -79.381480
# 3        220 Yonge St.     43.655965    -79.380541
# 4  249 Victoria Street     43.655641    -79.379199
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...                434
# 1  [{'label': 'display', 'lat': 43.65261436174172...                416
# 2  [{'label': 'display', 'lat': 43.65610066909799...                 51
# 3  [{'label': 'display', 'lat': 43.65596504293232...                 49
# 4  [{'label': 'display', 'lat': 43.65564091455335...                157
#
#   location.postalCode location.cc location.city location.state  \
# 0             M5G 1R3          CA       Toronto             ON
# 1             M5H 3X4          CA       Toronto             ON
# 2                 NaN          CA           NaN            NaN
# 3                 NaN          CA       Toronto             ON
# 4             M5B 1T8          CA       Toronto             ON
#
#   location.country                          location.formattedAddress  \
# 0           Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 2           Canada                                           [Canada]
# 3           Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 4           Canada  [249 Victoria Street (btwn Dundas St E and Shu...
#
#                    location.crossStreet venuePage.id
# 0                                   NaN          NaN
# 1                                   NaN          NaN
# 2                                   NaN          NaN
# 3  in Toronto Eaton Centre Urban Eatery          NaN
# 4        btwn Dundas St E and Shuter St     55585058

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                   name           categories  \
# 0      Hemispheres Restaurant & Bistro  American Restaurant
# 1  Richtree Natural Market Restaurants           Restaurant
# 2        Terrace Restaurant at Elmwood  American Restaurant
# 3   Akashiro Japanese Restaurant & Bar     Sushi Restaurant
# 4               The Senator Restaurant                Diner
# 5                               Subway       Sandwich Place
# 6                     Adega Restaurant           Restaurant
# 7        Hong Shing Chinese Restaurant   Chinese Restaurant
# 8      Kyoto House Japanese Restaurant     Sushi Restaurant
# 9         Yueh Tung Chinese Restaurant   Chinese Restaurant
#
#                address        lat        lng  \
# 0  110 Chestnut Street  43.654884 -79.385931
# 1        14 Queen St W  43.652614 -79.380231
# 2                  NaN  43.656101 -79.381480
# 3        220 Yonge St.  43.655965 -79.380541
# 4  249 Victoria Street  43.655641 -79.379199
# 5      10 Dundas St. E  43.656260 -79.380920
# 6            33 Elm St  43.657519 -79.383462
# 7      195 Dundas St W  43.654925 -79.387089
# 8  143 Dundas St. West  43.655381 -79.385270
# 9    126 Elizabeth St.  43.655281 -79.385337
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...       434    M5G 1R3  CA
# 1  [{'label': 'display', 'lat': 43.65261436174172...       416    M5H 3X4  CA
# 2  [{'label': 'display', 'lat': 43.65610066909799...        51        NaN  CA
# 3  [{'label': 'display', 'lat': 43.65596504293232...        49        NaN  CA
# 4  [{'label': 'display', 'lat': 43.65564091455335...       157    M5B 1T8  CA
# 5  [{'label': 'display', 'lat': 43.65625998968890...         6    M5B 2G9  CA
# 6  [{'label': 'display', 'lat': 43.65751886446546...       244    M5G 1H1  CA
# 7  [{'label': 'display', 'lat': 43.65492521335936...       520    M5G 1C7  CA
# 8  [{'label': 'display', 'lat': 43.65538110598594...       365        NaN  CA
# 9  [{'label': 'display', 'lat': 43.65528126342919...       374        NaN  CA
#
#       city state country                                   formattedAddress  \
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1  Toronto    ON  Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 2      NaN   NaN  Canada                                           [Canada]
# 3  Toronto    ON  Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 4  Toronto    ON  Canada  [249 Victoria Street (btwn Dundas St E and Shu...
# 5  Toronto    ON  Canada  [10 Dundas St. E (at Yonge St.), Toronto ON M5...
# 6  Toronto    ON  Canada  [33 Elm St (at Bay St), Toronto ON M5G 1H1, Ca...
# 7  Toronto    ON  Canada  [195 Dundas St W (at University Ave), Toronto ...
# 8  Toronto    ON  Canada          [143 Dundas St. West, Toronto ON, Canada]
# 9  Toronto    ON  Canada  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
#
#                             crossStreet                        id
# 0                                   NaN  4ad4c05ff964a52048f720e3
# 1                                   NaN  4b295e10f964a520ba9d24e3
# 2                                   NaN  4edbccaaf9abeea3db5268df
# 3  in Toronto Eaton Centre Urban Eatery  4fbbb3ace4b01e39077b4d55
# 4        btwn Dundas St E and Shuter St  4ad7929cf964a520500c21e3
# 5                          at Yonge St.  4c6abb8c2c29d13ad2720e41
# 6                             at Bay St  4ad4c060f964a52070f720e3
# 7                     at University Ave  4b2027b5f964a520f82d24e3
# 8                                   NaN  4ae4b055f964a520229d21e3
# 9                            Dundas St.  52a7ae41498eed3af4d0a3fa

# %%
dataframe_filtered.name
# Out:
# 0        Hemispheres Restaurant & Bistro
# 1    Richtree Natural Market Restaurants
# 2          Terrace Restaurant at Elmwood
# 3     Akashiro Japanese Restaurant & Bar
# 4                 The Senator Restaurant
# 5                                 Subway
# 6                       Adega Restaurant
# 7          Hong Shing Chinese Restaurant
# 8        Kyoto House Japanese Restaurant
# 9           Yueh Tung Chinese Restaurant
# Name: name, dtype: object

# %% [markdown]
# #### Generate map of the city’s downtown area

# %%
# Let’s locate the approximate center and explore neighboring restaurants
# Zoom in to visualize
# Note: Github may not display map

venues_map = folium.Map(location=[latitude, longitude], zoom_start=10) # generate map centred around 

# add a red circle marker to represent 
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Downtown Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Approximate Defined Center: Google Maps

# %%
# We searched cordinate 43.6563221, -79.3809161 for Downtown Toronto
# Result shows "418 The PATH - Yonge-Dundas Square, Toronto, ON M5B 1R4, Canada"
# Represented by a red circle marker from the generated map above

# %% [markdown]
# #### Dataframe Clean Up

# %%
# Let's sort by distance
sort_by_distance = dataframe_filtered.sort_values('distance')
sort_by_distance
# Out:
#                                   name           categories  \
# 5                               Subway       Sandwich Place
# 3   Akashiro Japanese Restaurant & Bar     Sushi Restaurant
# 2        Terrace Restaurant at Elmwood  American Restaurant
# 4               The Senator Restaurant                Diner
# 6                     Adega Restaurant           Restaurant
# 8      Kyoto House Japanese Restaurant     Sushi Restaurant
# 9         Yueh Tung Chinese Restaurant   Chinese Restaurant
# 1  Richtree Natural Market Restaurants           Restaurant
# 0      Hemispheres Restaurant & Bistro  American Restaurant
# 7        Hong Shing Chinese Restaurant   Chinese Restaurant
#
#                address        lat        lng  \
# 5      10 Dundas St. E  43.656260 -79.380920
# 3        220 Yonge St.  43.655965 -79.380541
# 2                  NaN  43.656101 -79.381480
# 4  249 Victoria Street  43.655641 -79.379199
# 6            33 Elm St  43.657519 -79.383462
# 8  143 Dundas St. West  43.655381 -79.385270
# 9    126 Elizabeth St.  43.655281 -79.385337
# 1        14 Queen St W  43.652614 -79.380231
# 0  110 Chestnut Street  43.654884 -79.385931
# 7      195 Dundas St W  43.654925 -79.387089
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 5  [{'label': 'display', 'lat': 43.65625998968890...         6    M5B 2G9  CA
# 3  [{'label': 'display', 'lat': 43.65596504293232...        49        NaN  CA
# 2  [{'label': 'display', 'lat': 43.65610066909799...        51        NaN  CA
# 4  [{'label': 'display', 'lat': 43.65564091455335...       157    M5B 1T8  CA
# 6  [{'label': 'display', 'lat': 43.65751886446546...       244    M5G 1H1  CA
# 8  [{'label': 'display', 'lat': 43.65538110598594...       365        NaN  CA
# 9  [{'label': 'display', 'lat': 43.65528126342919...       374        NaN  CA
# 1  [{'label': 'display', 'lat': 43.65261436174172...       416    M5H 3X4  CA
# 0  [{'label': 'display', 'lat': 43.65488413420439...       434    M5G 1R3  CA
# 7  [{'label': 'display', 'lat': 43.65492521335936...       520    M5G 1C7  CA
#
#       city state country                                   formattedAddress  \
# 5  Toronto    ON  Canada  [10 Dundas St. E (at Yonge St.), Toronto ON M5...
# 3  Toronto    ON  Canada  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 2      NaN   NaN  Canada                                           [Canada]
# 4  Toronto    ON  Canada  [249 Victoria Street (btwn Dundas St E and Shu...
# 6  Toronto    ON  Canada  [33 Elm St (at Bay St), Toronto ON M5G 1H1, Ca...
# 8  Toronto    ON  Canada          [143 Dundas St. West, Toronto ON, Canada]
# 9  Toronto    ON  Canada  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 1  Toronto    ON  Canada        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 0  Toronto    ON  Canada  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 7  Toronto    ON  Canada  [195 Dundas St W (at University Ave), Toronto ...
#
#                             crossStreet                        id
# 5                          at Yonge St.  4c6abb8c2c29d13ad2720e41
# 3  in Toronto Eaton Centre Urban Eatery  4fbbb3ace4b01e39077b4d55
# 2                                   NaN  4edbccaaf9abeea3db5268df
# 4        btwn Dundas St E and Shuter St  4ad7929cf964a520500c21e3
# 6                             at Bay St  4ad4c060f964a52070f720e3
# 8                                   NaN  4ae4b055f964a520229d21e3
# 9                            Dundas St.  52a7ae41498eed3af4d0a3fa
# 1                                   NaN  4b295e10f964a520ba9d24e3
# 0                                   NaN  4ad4c05ff964a52048f720e3
# 7                     at University Ave  4b2027b5f964a520f82d24e3

# %%
# Hide the index
sort_by_distance.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_e2b60da2_1b05_11ea_b381_029830e33458" ><thead>    <tr>        <th class="col_heading level0 col0" >name</th>        <th class="col_heading level0 col1" >categories</th>        <th class="col_heading level0 col2" >address</th>        <th class="col_heading level0 col3" >lat</th>        <th class="col_heading level0 col4" >lng</th>        <th class="col_heading level0 col5" >labeledLatLngs</th>        <th class="col_heading level0 col6" >distance</th>        <th class="col_heading level0 col7" >postalCode</th>        <th class="col_heading level0 col8" >cc</th>        <th class="col_heading level0 col9" >city</th>        <th class="col_heading level0 col10" >state</th>        <th class="col_heading level0 col11" >country</th>        <th class="col_heading level0 col12" >formattedAddress</th>        <th class="col_heading level0 col13" >crossStreet</th>        <th class="col_heading level0 col14" >id</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col0" class="data row0 col0" >Subway</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col1" class="data row0 col1" >Sandwich Place</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col2" class="data row0 col2" >10 Dundas St. E</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col3" class="data row0 col3" >43.6563</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col4" class="data row0 col4" >-79.3809</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col5" class="data row0 col5" >[{'label': 'display', 'lat': 43.656259989688905, 'lng': -79.38091959903076}]</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col6" class="data row0 col6" >6</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col7" class="data row0 col7" >M5B 2G9</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col8" class="data row0 col8" >CA</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col9" class="data row0 col9" >Toronto</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col10" class="data row0 col10" >ON</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col11" class="data row0 col11" >Canada</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col12" class="data row0 col12" >['10 Dundas St. E (at Yonge St.)', 'Toronto ON M5B 2G9', 'Canada']</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col13" class="data row0 col13" >at Yonge St.</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row0_col14" class="data row0 col14" >4c6abb8c2c29d13ad2720e41</td>
#             </tr>
#             <tr>
#                                 <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col0" class="data row1 col0" >Akashiro Japanese Restaurant & Bar</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col1" class="data row1 col1" >Sushi Restaurant</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col2" class="data row1 col2" >220 Yonge St.</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col3" class="data row1 col3" >43.656</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col4" class="data row1 col4" >-79.3805</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col5" class="data row1 col5" >[{'label': 'display', 'lat': 43.65596504293232, 'lng': -79.38054070644233}]</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col6" class="data row1 col6" >49</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col7" class="data row1 col7" >nan</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col8" class="data row1 col8" >CA</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col9" class="data row1 col9" >Toronto</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col10" class="data row1 col10" >ON</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col11" class="data row1 col11" >Canada</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col12" class="data row1 col12" >['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)', 'Toronto ON', 'Canada']</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col13" class="data row1 col13" >in Toronto Eaton Centre Urban Eatery</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row1_col14" class="data row1 col14" >4fbbb3ace4b01e39077b4d55</td>
#             </tr>
#             <tr>
#                                 <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col0" class="data row2 col0" >Terrace Restaurant at Elmwood</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col1" class="data row2 col1" >American Restaurant</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col2" class="data row2 col2" >nan</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col3" class="data row2 col3" >43.6561</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col4" class="data row2 col4" >-79.3815</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col5" class="data row2 col5" >[{'label': 'display', 'lat': 43.65610066909799, 'lng': -79.38148016065777}]</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col6" class="data row2 col6" >51</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col7" class="data row2 col7" >nan</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col8" class="data row2 col8" >CA</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col9" class="data row2 col9" >nan</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col10" class="data row2 col10" >nan</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col11" class="data row2 col11" >Canada</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col12" class="data row2 col12" >['Canada']</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col13" class="data row2 col13" >nan</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row2_col14" class="data row2 col14" >4edbccaaf9abeea3db5268df</td>
#             </tr>
#             <tr>
#                                 <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row3_col0" class="data row3 col0" >The Senator Restaurant</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row3_col1" class="data row3 col1" >Diner</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row3_col2" class="data row3 col2" >249 Victoria Street</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row3_col3" class="data row3 col3" >43.6556</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row3_col4" class="data row3 col4" >-79.3792</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row3_col5" class="data row3 col5" >[{'label': 'display', 'lat': 43.65564091455335, 'lng': -79.37919882575557}]</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row3_col6" class="data row3 col6" >157</td>
#                         <td id="T_e2b60da2_1b05_11ea_b381_029830e33458row3_col7" class="data row3 col7" >M5B 1T8</td>
#                         <td id="

# %% [markdown]
# #### Explore Restaurants using their ID

# %%
# Making calls to Foursquare API to get 'given values'
# The Senator Restaurant would be our pilot call
# We then get the Rating, Price, Tier and Currency for others

# %%
venue_id = '4ad7929cf964a520500c21e3' # ID of The Senator Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4ad7929cf964a520500c21e3?client_id=2IFJ4OSQ4YRJ4ZF2BZZQXUNDJSNK4F4JHIFZ2RUVKVZ2FPQH&client_secret=FFJNCIUYMDQFICJLZMSZATWNHBBZCTCCZLRLUU1Z3JYSXNIS&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']

# To simplify, output was cleared

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %%
try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
# Out:
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}

# %%
# Now we leverage the Foursquare location data to the fullest
# let's get the Rating, Price, Tier and Currency for other restaurants


venue_id = '4c6abb8c2c29d13ad2720e41' # Subway
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
    
venue_id = '4fbbb3ace4b01e39077b4d55' # Akashiro Japanese Restaurant & Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.') 
    
        
venue_id = '4edbccaaf9abeea3db5268df' # Terrace Restaurant at Elmwood
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '539c6f13498e06f4cc765165' # The Elm Tree Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    
    
venue_id = '5a8b24b2018cbb6c4ca70dae' # Hendricks Restaurant & Bar
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    

venue_id = '4ae4b055f964a520229d21e3' # Kyoto House Japanese Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
    

venue_id = '52a7ae41498eed3af4d0a3fa' # Yueh Tung Chinese Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')

venue_id = '4b295e10f964a520ba9d24e3' # Richtree Natural Market Restaurants
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')


venue_id = '4ad4c05ff964a52048f720e' # Hemispheres Restaurant & Bistro
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')

try:
    print(result['response']['venue']['price'])
except:
    print('No Details.')
# Out:
# 5.7
# {'tier': 1, 'message': 'Cheap', 'currency': '$'}
# 5.4
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 8.3
# No Details.
# 6.1
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 5.9
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# 7.8
# {'tier': 1, 'message': 'Cheap', 'currency': '$'}
# 6.2
# {'tier': 2, 'message': 'Moderate', 'currency': '$'}
# This venue has not been rated yet.
# No Details.

# %% [markdown]
# ##### Dataset Results above were extracted to csv format

# %%
# Let's get the csv file to create new dataframe
df_dtres = pd.read_csv('DT_Res.csv')
df_dtres
# Out:
#                             Restaurant Rating      Price Tier
# 0                               Subway     5.7     Cheap     1
# 1   Akashiro Japanese Restaurant & Bar     5.4  Moderate     2
# 2        Terrace Restaurant at Elmwood      NR  Moderate     2
# 3               The Senator Restaurant     7.9  Moderate     2
# 4              The Elm Tree Restaurant     8.3        ND    ND
# 5           Hendricks Restaurant & Bar     6.1  Moderate     2
# 6      Kyoto House Japanese Restaurant     5.9  Moderate     2
# 7         Yueh Tung Chinese Restaurant     7.8     Cheap     1
# 8  Richtree Natural Market Restaurants     6.2  Moderate     2
# 9      Hemispheres Restaurant & Bistro      NR        ND    ND

# %% [markdown]
# ##### New Dataframe: Price and Rating

# %%
# Look for word 'Cheap'
df_word=df_dtres[df_dtres['Price'].str.contains('Cheap')].reset_index(drop=True)

# Hide the index
df_word.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_e42862d4_1b05_11ea_b381_029830e33458" ><thead>    <tr>        <th class="col_heading level0 col0" >Restaurant</th>        <th class="col_heading level0 col1" >Rating </th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Tier </th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_e42862d4_1b05_11ea_b381_029830e33458row0_col0" class="data row0 col0" >Subway</td>
#                         <td id="T_e42862d4_1b05_11ea_b381_029830e33458row0_col1" class="data row0 col1" >5.7</td>
#                         <td id="T_e42862d4_1b05_11ea_b381_029830e33458row0_col2" class="data row0 col2" >Cheap</td>
#                         <td id="T_e42862d4_1b05_11ea_b381_029830e33458row0_col3" class="data row0 col3" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_e42862d4_1b05_11ea_b381_029830e33458row1_col0" class="data row1 col0" >Yueh Tung Chinese Restaurant</td>
#                         <td id="T_e42862d4_1b05_11ea_b381_029830e33458row1_col1" class="data row1 col1" >7.8</td>
#                         <td id="T_e42862d4_1b05_11ea_b381_029830e33458row1_col2" class="data row1 col2" >Cheap</td>
#                         <td id="T_e42862d4_1b05_11ea_b381_029830e33458row1_col3" class="data row1 col3" >1</td>
#             </tr>
#     </tbody></table>

# %%
# Look for word 'Moderate'
df_word=df_dtres[df_dtres['Price'].str.contains('Moderate')].reset_index(drop=True)

# Hide the index
df_word.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_e42a862c_1b05_11ea_b381_029830e33458" ><thead>    <tr>        <th class="col_heading level0 col0" >Restaurant</th>        <th class="col_heading level0 col1" >Rating </th>        <th class="col_heading level0 col2" >Price</th>        <th class="col_heading level0 col3" >Tier </th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_e42a862c_1b05_11ea_b381_029830e33458row0_col0" class="data row0 col0" >Akashiro Japanese Restaurant & Bar</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row0_col1" class="data row0 col1" >5.4</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row0_col2" class="data row0 col2" >Moderate</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row0_col3" class="data row0 col3" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_e42a862c_1b05_11ea_b381_029830e33458row1_col0" class="data row1 col0" >Terrace Restaurant at Elmwood</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row1_col1" class="data row1 col1" >NR</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row1_col2" class="data row1 col2" >Moderate</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row1_col3" class="data row1 col3" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_e42a862c_1b05_11ea_b381_029830e33458row2_col0" class="data row2 col0" >The Senator Restaurant</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row2_col1" class="data row2 col1" >7.9</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row2_col2" class="data row2 col2" >Moderate</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row2_col3" class="data row2 col3" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_e42a862c_1b05_11ea_b381_029830e33458row3_col0" class="data row3 col0" >Hendricks Restaurant & Bar</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row3_col1" class="data row3 col1" >6.1</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row3_col2" class="data row3 col2" >Moderate</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row3_col3" class="data row3 col3" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_e42a862c_1b05_11ea_b381_029830e33458row4_col0" class="data row4 col0" >Kyoto House Japanese Restaurant</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row4_col1" class="data row4 col1" >5.9</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row4_col2" class="data row4 col2" >Moderate</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row4_col3" class="data row4 col3" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_e42a862c_1b05_11ea_b381_029830e33458row5_col0" class="data row5 col0" >Richtree Natural Market Restaurants</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row5_col1" class="data row5 col1" >6.2</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row5_col2" class="data row5 col2" >Moderate</td>
#                         <td id="T_e42a862c_1b05_11ea_b381_029830e33458row5_col3" class="data row5 col3" >2</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ##### Top picks by Price and Rating: Yueh Tung Chinese Restaurant and The Senator Restaurant

# %% [markdown]
# #### Final Deliverables

# %% [markdown]
# In Week 2, we will cover:
# * Components: Methodology, Analysis, Results and Discussion, Conclusion
# * Full Report with Components and Presentation
